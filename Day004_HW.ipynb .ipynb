# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13112504215","type":"DeleteEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":285155887,"name":"direwolf-github/my-app-4aa26e7b","url":"https://api.github.com/repos/direwolf-github/my-app-4aa26e7b"},"payload":{"ref":"branch-599e7b9c","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2020-08-05T02:24:41Z"},{"id":"13112504213","type":"PullRequestEvent","actor":{"id":308430,"login":"mokevnin","display_login":"mokevnin","gravatar_id":"","url":"https://api.github.com/users/mokevnin","avatar_url":"https://avatars.githubusercontent.com/u/308430?"},"repo":{"id":261513187,"name":"hexlet-basics/hexlet-basics","url":"https://api.github.com/repos/hexlet-basics/hexlet-basics"},"payload":{"action":"closed","number":54,"pull_request":{"url":"https://api.github.com/repos/hexlet-basics/h
# ...

# %%
'[{"id":"9911330792","type":"PushEvent","actor":{"id":11312017,"login":"pbaffiliate4","display_login":"pbaffiliate4","gravatar_id":"","url":"https://api.github.com/users/pbaffiliate4","avatar_url":"https://avatars.githubusercontent.com/u/11312017?"},"repo":{"id":153577238,"name":"pbaffiliate4/repoForSettings","url":"https://api.github.com/repos/pbaffiliate4/repoForSettings"},"payload":{"push_id":3762296191,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"be9d8ea6b6737192cd4710bf8884125c92acbcc5","before":"bc9fd090c7811ba2b489ef60571abd8c5d413f23","commits":[{"sha":"be9d8ea6b6737192cd4710bf8884125c92acbcc5","author":{"email":"pbaffiliate4@gmail.com","name":"Afaf Zakhya"},"message":"Test - Clear repository branch","distinct":true,"url":"https://api.github.com/repos/pbaffiliate4/repoForSettings/commits/be9d8ea6b6737192cd4710bf8884125c92acbcc5"}]},"public":true,"created_at":"2019-06-28T05:28:39Z"},{"id":"9911330783","type":"PullRequestEvent","actor":{"id":10598,"login":"ketan","display_login":"ketan","gravatar_id":"","url":"https://api.github.com/users/ketan","avatar_url":"https://avatars.githubusercontent.com/u/10598?"},"repo":{"id":15217919,"name":"gocd/www.go.cd","url":"https://api.github.com/repos/gocd/www.go.cd"},"payload":{"action":"closed","number":975,"pull_request":{"url":"https://api.github.com/repos/gocd/www.go.cd/pulls/975","id":278535640,"node_id":"MDExOlB1bGxSZXF1ZXN0Mjc4NTM1NjQw","html_url":"https://github.com/gocd/www.go.cd/pull/975","diff_url":"https://github.com/gocd/www.go.cd/pull/975.diff","patch_url":"https://github.com/gocd/www.go.cd/pull/975.patch","issue_url":"https://api.github.com/repos/gocd/www.go.cd/issues/975","number":975,"state":"closed","locked":false,"title":"Bump middleman from 4.3.2 to 4.3.4","user":{"login":"dependabot-preview[bot]","id":27856297,"node_id":"MDM6Qm90Mjc4NTYyOTc=","avatar_url":"https://avatars3.githubusercontent.com/in/2141?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview%5Bbot%5D","html_url":"https://github.com/apps/dependabot-preview","followers_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [middleman](https://github.com/middleman/middleman) from 4.3.2 to 4.3.4.\\n<details>\\n<summary>Commits</summary>\\n\\n- [`9482996`](https://github.com/middleman/middleman/commit/9482996d0c97bfc1d5949fa0527fb3cac3516734) Disable bind test on travis\\n- [`8091cb4`](https://github.com/middleman/middleman/commit/8091cb469847bb3e83ec5dd649b0437ebb6ddaa1) Lock old bundler\\n- [`ab1fc00`](https://github.com/middleman/middleman/commit/ab1fc00e6e569588c06a2cd5795f9a5e2da2e8ae) Bump minor\\n- [`b450db2`](https://github.com/middleman/middleman/commit/b450db2fc4317220bbddf6c45397d74cbbc73b41) Fix ignore of I18n files ([#2143](https://github-redirect.dependabot.com/middleman/middleman/issues/2143))\\n- [`f67ae38`](https://github.com/middleman/middleman/commit/f67ae38da59551c1629f70d7ca780b8402c3ae93) Bump again\\n- [`d53e3c6`](https://github.com/middleman/middleman/commit/d53e3c6d8ff6fdf90e1f58b79cd6df0b9f804035) Bump\\n- [`95c234f`](https://github.com/middleman/middleman/commit/95c234f7194ba8916b108082b788d774cf73f0e9) Add --bail option to fail upon first error ([#2246](https://github-redirect.dependabot.com/middleman/middleman/issues/2246))\\n- [`fc01a6c`](https://github.com/middleman/middleman/commit/fc01a6c4b823056f262324d7fc05b306319d469c) Fix lambda syntax\\n- [`dae9203`](https://github.com/middleman/middleman/commit/dae9203e8c9b7973c3f15d17d421ec89949d5777) Feature: Add an option to create asset hashes without using the original file...\\n- See full diff in [compare view](https://github.com/middleman/middleman/compare/v4.3.2...v4.3.4)\\n</details>\\n<br />\\n\\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=middleman&package-manager=bundler&previous-version=4.3.2&new-version=4.3.4)](https://dependabot.com/compatibility-score.html?dependency-name=middleman&package-manager=bundler&previous-version=4.3.2&new-version=4.3.4)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\\n- `@dependabot badge me` will comment on this PR with code to add a \\"Dependabot enabled\\" badge to your readme\\n\\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\\n- Update frequency (including time of day and day of week)\\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\\n- Pull request limits (per update run and/or open at any time)\\n- Out-of-range updates (receive only lockfile updates, if desired)\\n- Security updates (receive only security updates, if desired)\\n\\nFinally, you can contact us by mentioning @dependabot.\\n\\n</details>","created_at":"2019-05-14T06:23:29Z","updated_at":"2019-06-28T05:28:39Z","closed_at":"2019-06-28T05:28:39Z","merged_at":"2019-06-28T05:28:39Z","merge_commit_sha":"2a0bca4c51036df50db45f1cbe61aa6c3f2cd2f6","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[{"id":1186592167,"node_id":"MDU6TGFiZWwxMTg2NTkyMTY3","url":"https://api.github.com/repos/gocd/www.go.cd/labels/dependencies","name":"dependencies","color":"0025ff","default":false}],"milestone":null,"commits_url":"https://api.github.com/repos/gocd/www.go.cd/pulls/975/commits","review_comments_url":"https://api.github.com/repos/gocd/www.go.cd/pulls/975/comments","review_comment_url":"https://api.github.com/repos/gocd/www.go.cd/pulls/comments{/number}","comments_url":"https://api.github.com/repos/gocd/www.go.cd/issues/975/comments","statuses_url":"https://api.github.com/repos/gocd/www.go.cd/statuses/3f17cd5a5ca018666bed97f4e07ae4c707ae675c","head":{"label":"gocd:dependabot/bundler/middleman-4.3.4","ref":"dependabot/bundler/middleman-4.3.4","sha":"3f17cd5a5ca018666bed97f4e07ae4c707ae675c","user":{"login":"gocd","id":6099846,"node_id":"MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=","avatar_url":"https://avatars1.githubusercontent.com/u/6099846?v=4","gravatar_id":"","url":"https://api.github.com/users/gocd","html_url":"https://github.com/gocd","followers_url":"https://api.github.com/users/gocd/followers","following_url":"https://api.github.com/users/gocd/following{/other_user}","gists_url":"https://api.github.com/users/gocd/gists{/gist_id}","starred_url":"https://api.github.com/users/gocd/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gocd/subscriptions","organizations_url":"https://api.github.com/users/gocd/orgs","repos_url":"https://api.github.com/users/gocd/repos","events_url":"https://api.github.com/users/gocd/events{/privacy}","received_events_url":"https://api.github.com/users/gocd/received_events","type":"Organization","site_admin":false},"repo":{"id":15217919,"node_id":"MDEwOlJlcG9zaXRvcnkxNTIxNzkxOQ==","name":"www.go.cd","full_name":"gocd/www.go.cd","private":false,"owner":{"login":"gocd","id":6099846,"node_id":"MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=","avatar_url":"https://avatars1.githubusercontent.com/u/6099846?v=4","gravatar_id":"","url":"https://api.github.com/users/gocd","html_url":"https://github.com/gocd","followers_url":"https://api.github.com/users/gocd/followers","following_url":"https://api.github.com/users/gocd/following{/other_user}","gists_url":"https://api.github.com/users/gocd/gists{/gist_id}","starred_url":"https://api.github.com/users/gocd/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gocd/subscriptions","organizations_url":"https://api.github.com/users/gocd/orgs","repos_url":"https://api.github.com/users/gocd/repos","events_url":"https://api.github.com/users/gocd/events{/privacy}","received_events_url":"https://api.github.com/users/gocd/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/gocd/www.go.cd","description":"Github pages repo ","fork":false,"url":"https://api.github.com/repos/gocd/www.go.cd","forks_url":"https://api.github.com/repos/gocd/www.go.cd/forks","keys_url":"https://api.github.com/repos/gocd/www.go.cd/keys{/key_id}","collaborators_url":"https://api.github.com/repos/gocd/www.go.cd/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/gocd/www.go.cd/teams","hooks_url":"https://api.github.com/repos/gocd/www.go.cd/hooks","issue_events_url":"https://api.github.com/repos/gocd/www.go.cd/issues/events{/number}","events_url":"https://api.github.com/repos/gocd/www.go.cd/events","assignees_url":"https://api.github.com/repos/gocd/www.go.cd/assignees{/user}","branches_url":"https://api.github.com/repos/gocd/www.go.cd/branches{/branch}","tags_url":"https://api.github.com/repos/gocd/www.go.cd/tags","blobs_url":"https://api.github.com/repos/gocd/www.go.cd/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/gocd/www.go.cd/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/gocd/www.go.cd/git/refs{/sha}","trees_url":"https://api.github.com/repos/gocd/www.go.cd/git/trees{/sha}","statuses_url":"https://api.github.com/repos/gocd/www.go.cd/statuses/{sha}","languages_url":"https://api.github.com/repos/gocd/www.go.cd/languages","stargazers_url":"https://api.github.com/repos/gocd/www.go.cd/stargazers","contributors_url":"https://api.github.com/repos/gocd/www.go.cd/contributors","subscribers_url":"https://api.github.com/repos/gocd/www.go.cd/subscribers","subscription_url":"https://api.github.com/repos/gocd/www.go.cd/subscription","commits_url":"https://api.github.com/repos/gocd/www.go.cd/commits{/sha}","git_commits_url":"https://api.github.com/repos/gocd/www.go.cd/git/commits{/sha}","comments_url":"https://api.github.com/repos/gocd/www.go.cd/comments{/number}","issue_comment_url":"https://api.github.com/repos/gocd/www.go.cd/issues/comments{/number}","contents_url":"https://api.github.com/repos/gocd/www.go.cd/contents/{+path}","compare_url":"https://api.github.com/repos/gocd/www.go.cd/compare/{base}...{head}","merges_url":"https://api.github.com/repos/gocd/www.go.cd/merges","archive_url":"https://api.github.com/repos/gocd/www.go.cd/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/gocd/www.go.cd/downloads","issues_url":"https://api.github.com/repos/gocd/www.go.cd/issues{/number}","pulls_url":"https://api.github.com/repos/gocd/www.go.cd/pulls{/number}","milestones_url":"https://api.github.com/repos/gocd/www.go.cd/milestones{/number}","notifications_url":"https://api.github.com/repos/gocd/www.go.cd/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/gocd/www.go.cd/labels{/name}","releases_url":"https://api.github.com/repos/gocd/www.go.cd/releases{/id}","deployments_url":"https://api.github.com/repos/gocd/www.go.cd/deployments","created_at":"2013-12-16T05:36:20Z","updated_at":"2019-06-28T05:22:55Z","pushed_at":"2019-06-28T05:28:39Z","git_url":"git://github.com/gocd/www.go.cd.git","ssh_url":"git@github.com:gocd/www.go.cd.git","clone_url":"https://github.com/gocd/www.go.cd.git","svn_url":"https://github.com/gocd/www.go.cd","homepage":"https://www.gocd.org","size":199801,"stargazers_count":40,"watchers_count":40,"language":"HTML","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":false,"has_pages":true,"forks_count":111,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count
git/tags{/sha}","git_refs_url":"https://api.github.com/repos/gocd/www.go.cd/git/refs{/sha}","trees_url":"https://api.github.com/repos/gocd/www.go.cd/git/trees{/sha}","statuses_url":"https://api.github.com/repos/gocd/www.go.cd/statuses/{sha}","languages_url":"https://api.github.com/repos/gocd/www.go.cd/languages","stargazers_url":"https://api.github.com/repos/gocd/www.go.cd/stargazers","contributors_url":"https://api.github.com/repos/gocd/www.go.cd/contributors","subscribers_url":"https://api.github.com/repos/gocd/www.go.cd/subscribers","subscription_url":"https://api.github.com/repos/gocd/www.go.cd/subscription","commits_url":"https://api.github.com/repos/gocd/www.go.cd/commits{/sha}","git_commits_url":"https://api.github.com/repos/gocd/www.go.cd/git/commits{/sha}","comments_url":"https://api.github.com/repos/gocd/www.go.cd/comments{/number}","issue_comment_url":"https://api.github.com/repos/gocd/www.go.cd/issues/comments{/number}","contents_url":"https://api.github.com/repos/gocd/www.go.cd/contents/{+path}","compare_url":"https://api.github.com/repos/gocd/www.go.cd/compare/{base}...{head}","merges_url":"https://api.github.com/repos/gocd/www.go.cd/merges","archive_url":"https://api.github.com/repos/gocd/www.go.cd/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/gocd/www.go.cd/downloads","issues_url":"https://api.github.com/repos/gocd/www.go.cd/issues{/number}","pulls_url":"https://api.github.com/repos/gocd/www.go.cd/pulls{/number}","milestones_url":"https://api.github.com/repos/gocd/www.go.cd/milestones{/number}","notifications_url":"https://api.github.com/repos/gocd/www.go.cd/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/gocd/www.go.cd/labels{/name}","releases_url":"https://api.github.com/repos/gocd/www.go.cd/releases{/id}","deployments_url":"https://api.github.com/repos/gocd/www.go.cd/deployments","created_at":"2013-12-16T05:36:20Z","updated_at":"2019-06-28T05:22:55Z","pushed_at":"2019-06-28T05:28:39Z","git_url":"git://github.com/gocd/www.go.cd.git","ssh_url":"git@github.com:gocd/www.go.cd.git","clone_url":"https://github.com/gocd/www.go.cd.git","svn_url":"https://github.com/gocd/www.go.cd","homepage":"https://www.gocd.org","size":199801,"stargazers_count":40,"watchers_count":40,"language":"HTML","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":false,"has_pages":true,"forks_count":111,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":26,"license":{"key":"apache-2.0","name":"Apache License 2.0","spdx_id":"Apache-2.0","url":"https://api.github.com/licenses/apache-2.0","node_id":"MDc6TGljZW5zZTI="},"forks":111,"open_issues":26,"watchers":40,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/gocd/www.go.cd/pulls/975"},"html":{"href":"https://github.com/gocd/www.go.cd/pull/975"},"issue":{"href":"https://api.github.com/repos/gocd/www.go.cd/issues/975"},"comments":{"href":"https://api.github.com/repos/gocd/www.go.cd/issues/975/comments"},"review_comments":{"href":"https://api.github.com/repos/gocd/www.go.cd/pulls/975/comments"},"review_comment":{"href":"https://api.github.com/repos/gocd/www.go.cd/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/gocd/www.go.cd/pulls/975/commits"},"statuses":{"href":"https://api.github.com/repos/gocd/www.go.cd/statuses/3f17cd5a5ca018666bed97f4e07ae4c707ae675c"}},"author_association":"CONTRIBUTOR","merged":true,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":{"login":"ketan","
":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/278a29c6426325adee0f5de64e46224061260185"},{"sha":"635461aa58d98f80ba37ccd0a70a6c4521409838","author":{"email":"ira.d.sanchez@gmail.com","name":"iradsanchez"},"message":"Add Stripe Redirect\\n\\nRedirect itself is working, but when sending a verification text, it breaks. Stripe is working on a solution and will get back to me.","distinct":false,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/635461aa58d98f80ba37ccd0a70a6c4521409838"},{"sha":"b00d0c8330d1e6758e7e98915b99177a4518e7cc","author":{"email":"tom@edgegluer.com","name":"unknown"},"message":" username now rendering to the chat box","distinct":false,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/b00d0c8330d1e6758e7e98915b99177a4518e7cc"},{"sha":"93ee8684d13afb717655911f23c75bf6a5f0766b","author":{"email":"42781255+ThomasUtsey@users.noreply.github.com","name":"ThomasUtsey"},"message":"Merge pull request #76 from labslibrarypt3/tom-restricted\\n\\n username now rendering to the chat box","distinct":false,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/93ee8684d13afb717655911f23c75bf6a5f0766b"},{"sha":"26ec0d6fffff65448247d7e8b95863a6bea94031","author":{"email":"42781255+ThomasUtsey@users.noreply.github.com","name":"ThomasUtsey"},"message":"Merge pull request #77 from labslibrarypt3/ira-sanchez\\n\\nIra sanchez","distinct":false,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/26ec0d6fffff65448247d7e8b95863a6bea94031"},{"sha":"0db8637f12da6713066c21c16a1579962cd7f479","author":{"email":"42781255+ThomasUtsey@users.noreply.github.com","name":"ThomasUtsey"},"message":"Merge pull request #78 from labslibrarypt3/development\\n\\nDevelopment","distinct":true,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/0db8637f12da6713066c21c16a1579962cd7f479"}]},"public":true,"created_at":"2019-06-28T05:28:39Z","org":{"id":50470163,"login":"labslibrarypt3","gravatar_id":"","url":"https://api.github.com/orgs/labslibrarypt3","avatar_url":"https://avatars.githubusercontent.com/u/50470163?"}},{"id":"9911330773","type":"CreateEvent","actor":{"id":12807798,"login":"augsun","display_login":"augsun","gravatar_id":"","url":"https://api.github.com/users/augsun","avatar_url":"https://avatars.githubusercontent.com/u/12807798?"},"repo":{"id":171888030,"name":"augsun/JXCapital","url":"https://api.github.com/repos/augsun/JXCapital"},"payload":{"ref":"0.1.22","ref_type":"tag","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-06-28T05:28:39Z"},{"id":"9911330761","type":"PullRequestEvent","actor":{"id":8593673,"login":"derrickmehaffy","display_login":"derrickmehaffy","gravatar_id":"","url":"https://api.github.com/users/derrickmehaffy","avatar_url":"https://avatars.githubusercontent.com/u/8593673?"},"repo":{"id":133168196,"name":"canonn-science/CAPIv2-Strapi","url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi"},"payload":{"action":"opened","number":136,"pull_request":{"url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136","id":292692943,"node_id":"MDExOlB1bGxSZXF1ZXN0MjkyNjkyOTQz","html_url":"https://github.com/canonn-science/CAPIv2-Strapi/pull/136","diff_url":"https://github.com/canonn-science/CAPIv2-Strapi/pull/136.diff","patch_url":"https://github.com/canonn-science/CAPIv2-Strapi/pull/136.patch","issue_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi
":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi","forks_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/forks","keys_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/keys{/key_id}","collaborators_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/teams","hooks_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/hooks","issue_events_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/events{/number}","events_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/events","assignees_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/assignees{/user}","branches_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/branches{/branch}","tags_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/tags","blobs_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/refs{/sha}","trees_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/trees{/sha}","statuses_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/{sha}","languages_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/languages","stargazers_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/stargazers","contributors_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contributors","subscribers_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscribers","subscription_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscription","commits_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/commits{/sha}","git_commits_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/commits{/sha}","comments_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/comments{/number}","issue_comment_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/comments{/number}","contents_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contents/{+path}","compare_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/compare/{base}...{head}","merges_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/merges","archive_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/downloads","issues_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues{/number}","pulls_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls{/number}","milestones_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/milestones{/number}","notifications_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/labels{/name}","releases_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/releases{/id}","deployments_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/deployments","created_at":"2018-05-12T17:25:27Z","updated_at":"2019-06-25T03:17:57Z","pushed_at":"2019-06-28T04:32:40Z","git_url":"git://github.com/canonn-science/CAPIv2-Strapi.git","ssh_url":"git@github.com:canonn-science/CAPIv2-Strapi.git","clone_url":"https://github.com/canonn-science/CAPIv2-Strapi.git","svn_url":"https://github.com/canonn-science/CAPIv2-Strapi","homepage":"https://api.canonn.tech","size":196583,"stargazers_count":14,"watchers_count":14,"language":"TSQL","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":false,"has_pages":false,"forks_count":1,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":9,"license":{"key":"gpl-3.0","name":"GNU General Public License v3.0","spdx_id":"GPL-3.0","url":"https://api.github.com/licenses/gpl-3.0","node_id":"MDc6TGljZW5zZTk="},"forks":1,"open_issues":9,"watchers":14,"default_branch":"development"}},"base":{"label":"canonn-science:development","ref":"development","sha":"5212f803daded52429b65e244ad1873110394590","user":{"login":"canonn-science","id":25851850,"node_id":"MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw","avatar_url":"https://avatars0.githubusercontent.com/u/25851850?v=4","gravatar_id":"","url":"https://api.github.com/users/canonn-science","html_url":"https://github.com/canonn-science","followers_url":"https://api.github.com/users/canonn-science/followers","following_url":"https://api.github.com/users/canonn-science/following{/other_user}","gists_url":"https://api.github.com/users/canonn-science/gists{/gist_id}","starred_url":"https://api.github.com/users/canonn-science/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/canonn-science/subscriptions","organizations_url":"https://api.github.com/users/canonn-science/orgs","repos_url":"https://api.github.com/users/canonn-science/repos","events_url":"https://api.github.com/users/canonn-science/events{/privacy}","received_events_url":"https://api.github.com/users/canonn-science/received_events","type":"Organization","site_admin":false},"repo":{"id":133168196,"node_id":"MDEwOlJlcG9zaXRvcnkxMzMxNjgxOTY=","name":"CAPIv2-Strapi","full_name":"canonn-science/CAPIv2-Strapi","private":false,"owner":{"login":"canonn-science","id":25851850,"node_id":"MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw","avatar_url":"https://avatars0.githubusercontent.com/u/25851850?v=4","gravatar_id":"","url":"https://api.github.com/users/canonn-science","html_url":"https://github.com/canonn-science","followers_url":"https://api.github.com/users/canonn-science/followers","following_url":"https://api.github.com/users/canonn-science/following{/other_user}","gists_url":"https://api.github.com/users/canonn-science/gists{/gist_id}","starred_url":"https://api.github.com/users/canonn-science/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/canonn-science/subscriptions","organizations_url":"https://api.github.com/users/canonn-science/orgs","repos_url":"https://api.github.com/users/canonn-science/repos","events_url":"https://api.github.com/users/canonn-science/events{/privacy}","received_events_url":"https://api.github.com/users/canonn-science/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/canonn-science/CAPIv2-Strapi","description":"Canonn APIv2","fork":false,"url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi","forks_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/forks","keys_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/keys{/key_id}","collaborators_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/teams","hooks_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/hooks","issue_events_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/events{/number}","events_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/events","assignees_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/assignees{/user}","branches_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/branches{/branch}","tags_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/tags","blobs_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/refs{/sha}","trees_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/trees{/sha}","statuses_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/{sha}","languages_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/languages","stargazers_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/stargazers","contributors_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contributors","subscribers_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscribers","subscription_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscription","commits_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/commits{/sha}","git_commits_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/commits{/sha}","comments_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/comments{/number}","issue_comment_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/comments{/number}","contents_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contents/{+path}","compare_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/compare/{base}...{head}","merges_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/merges","archive_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/downloads","issues_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues{/number}","pulls_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls{/number}","milestones_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/milestones{/number}","notifications_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/labels{/name}","releases_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/releases{/id}","deployments_url":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/deployments","created_at":"2018-05-12T17:25:27Z","updated_at":"2019-06-25T03:17:57Z","pushed_at":"2019-06-28T04:32:40Z","git_url":"git://github.com/canonn-science/CAPIv2-Strapi.git","ssh_url":"git@github.com:canonn-science/CAPIv2-Strapi.git","clone_url":"https://github.com/canonn-science/CAPIv2-Strapi.git","svn_url":"https://github.com/canonn-science/CAPIv2-Strapi","homepage":"https://api.canonn.tech","size":196583,"stargazers_count":14,"watchers_count":14,"language":"TSQL","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":false,"has_pages":false,"forks_count":1,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":9,"license":{"key":"gpl-3.0","name":"GNU General Public License v3.0","spdx_id":"GPL-3.0","url":"https://api.github.com/licenses/gpl-3.0","node_id":"MDc6TGljZW5zZTk="},"forks":1,"open_issues":9,"watchers":14,"default_branch":"development"}},"_links":{"self":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136"},"html":{"href":"https://github.com/canonn-science/CAPIv2-Strapi/pull/136"},"issue":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/136"},"comments":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/136/comments"},"review_comments":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136/comments"},"review_comment":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136/commits"},"statuses":{"href":"https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/9d6e078d0a74179b0ad95703fc26fefd9bf53755"}},"author_association":"CONTRIBUTOR","merged":false,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":null,"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":3,"additions":270,"deletions":249,"changed_files":4}},"public":true,"created_at":"2019-06-28T05:28:39Z","org":{"id":25851850,"login":"canonn-science","gravatar_id":"","url":"https://api.github.com/orgs/canonn-science","avatar_url":"https://avatars.githubusercontent.com/u/25851850?"}},{"id":"9911330759","type":"PullRequestEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":137990332,"name":"BioWareRu/BioEngine.BRC.Admin","url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin"},"payload":{"action":"opened","number":256,"pull_request":{"url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256","id":292692951,"node_id":"MDExOlB1bGxSZXF1ZXN0MjkyNjkyOTUx","html_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin/pull/256","diff_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin/pull/256.diff","patch_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin/pull/256.patch","issue_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/256","number":256,"state":"open","locked":false,"title":"Bump @angular-devkit/build-angular from 0.800.3 to 0.800.6","user":{"login":"dependabot-preview[bot]","id":27856297,"node_id":"MDM6Qm90Mjc4NTYyOTc=","avatar_url":"https://avatars3.githubusercontent.com/in/2141?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview%5Bbot%5D","html_url":"https://github.com/apps/dependabot-preview","followers_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [@angular-devkit/build-angular](https://github.com/angular/angular-cli) from 0.800.3 to 0.800.6.\\n<details>\\n<summary>Commits</summary>\\n\\n- See full diff in [compare view](https://github.com/angular/angular-cli/commits)\\n</details>\\n<br />\\n\\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=@angular-devkit/build-angular&package-manager=npm_and_yarn&previous-version=0.800.3&new-version=0.800.6)](https://dependabot.com/compatibility-score.html?dependency-name=@angular-devkit/build-angular&package-manager=npm_and_yarn&previous-version=0.800.3&new-version=0.800.6)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\\n- `@dependabot badge me` will comment on this PR with code to add a \\"Dependabot enabled\\" badge to your readme\\n\\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\\n- Update frequency (including time of day and day of week)\\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\\n- Pull request limits (per update run and/or open at any time)\\n- Out-of-range updates (receive only lockfile updates, if desired)\\n- Security updates (receive only security updates, if desired)\\n\\nFinally, you can contact us by mentioning @dependabot.\\n\\n</details>","created_at":"2019-06-28T05:28:38Z","updated_at":"2019-06-28T05:28:38Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256/commits","review_comments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256/comments","review_comment_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/comments{/number}","comments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/256/comments","statuses_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/statuses/fd926c4d44f91d084bf0060a6b1af1ce9054e34e","head":{"label":"BioWareRu:dependabot/npm_and_yarn/@angular-devkit/build-angular-0.800.6","ref":"dependabot/npm_and_yarn/@angular-devkit/build-angular-0.800.6","sha":"fd926c4d44f91d084bf0060a6b1af1ce9054e34e","user":{"login":"BioWareRu","id":22096408,"node_id":"MDEyOk9yZ2FuaXphdGlvbjIyMDk2NDA4","avatar_url":"https://avatars0.githubusercontent.com/u/22096408?v=4","gravatar_id":"","url":"https://api.github.com/users/BioWareRu","html_url":"https://github.com/BioWareRu","followers_url":"https://api.github.com/users/BioWareRu/followers","following_url":"https://api.github.com/users/BioWareRu/following{/other_user}","gists_url":"https://api.github.com/users/BioWareRu/gists{/gist_id}","starred_url":"https://api.github.com/users/BioWareRu/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BioWareRu/subscriptions","organizations_url":"https://api.github.com/users/BioWareRu/orgs","repos_url":"https://api.github.com/users/BioWareRu/repos","events_url":"https://api.github.com/users/BioWareRu/events{/privacy}","received_events_url":"https://api.github.com/users/BioWareRu/received_events","type":"Organization","site_admin":false},"repo":{"id":137990332,"node_id":"MDEwOlJlcG9zaXRvcnkxMzc5OTAzMzI=","name":"BioEngine.BRC.Admin","full_name":"BioWareRu/BioEngine.BRC.Admin","private":false,"owner":{"login":"BioWareRu","id":22096408,"node_id":"MDEyOk9yZ2FuaXphdGlvbjIyMDk2NDA4","avatar_url":"https://avatars0.githubusercontent.com/u/22096408?v=4","gravatar_id":"","url":"https://api.github.com/users/BioWareRu","html_url":"https://github.com/BioWareRu","followers_url":"https://api.github.com/users/BioWareRu/followers","following_url":"https://api.github.com/users/BioWareRu/following{/other_user}","gists_url":"https://api.github.com/users/BioWareRu/gists{/gist_id}","starred_url":"https://api.github.com/users/BioWareRu/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BioWareRu/subscriptions","organizations_url":"https://api.github.com/users/BioWareRu/orgs","repos_url":"https://api.github.com/users/BioWareRu/repos","events_url":"https://api.github.com/users/BioWareRu/events{/privacy}","received_events_url":"https://api.github.com/users/BioWareRu/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin","description":"Angular interface for BioEngine.API","fork":false,"url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin","forks_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/forks","keys_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/keys{/key_id}","collaborators_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/teams","hooks_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/hooks","issue_events_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/events{/number}","events_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/events","assignees_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/assignees{/user}","branches_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/branches{/branch}","tags_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/tags","blobs_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/refs{/sha}","trees_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/trees{/sha}","statuses_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/statuses/{sha}","languages_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/languages","stargazers_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/stargazers","contributors_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/contributors","subscribers_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/subscribers","subscription_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/subscription","commits_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/commits{/sha}","git_commits_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/commits{/sha}","comments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/comments{/number}","issue_comment_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/comments{/number}","contents_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/contents/{+path}","compare_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/compare/{base}...{head}","merges_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/merges","archive_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/downloads","issues_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues{/number}","pulls_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls{/number}","milestones_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/milestones{/number}","notifications_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/labels{/name}","releases_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/releases{/id}","deployments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/deployments","created_at":"2018-06-20T06:36:26Z","updated_at":"2019-06-25T11:27:13Z","pushed_at":"2019-06-28T05:28:38Z","git_url":"git://github.com/BioWareRu/BioEngine.BRC.Admin.git","ssh_url":"git@github.com:BioWareRu/BioEngine.BRC.Admin.git","clone_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin.git","svn_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin","homepage":null,"size":2713,"stargazers_count":0,"watchers_count":0,"language":"TypeScript","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":5,"license":{"key":"mit","name":"MIT License","spdx_id":"MIT","url":"https://api.github.com/licenses/mit","node_id":"MDc6TGljZW5zZTEz"},"forks":0,"open_issues":5,"watchers":0,"default_branch":"master"}},"base":{"label":"BioWareRu:master","ref":"master","sha":"254dc54ae9d05cf21ab1c2bc95fb9c039c51bd11","user":{"login":"BioWareRu","id":22096408,"node_id":"MDEyOk9yZ2FuaXphdGlvbjIyMDk2NDA4","avatar_url":"https://avatars0.githubusercontent.com/u/22096408?v=4","gravatar_id":"","url":"https://api.github.com/users/BioWareRu","html_url":"https://github.com/BioWareRu","followers_url":"https://api.github.com/users/BioWareRu/followers","following_url":"https://api.github.com/users/BioWareRu/following{/other_user}","gists_url":"https://api.github.com/users/BioWareRu/gists{/gist_id}","starred_url":"https://api.github.com/users/BioWareRu/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BioWareRu/subscriptions","organizations_url":"https://api.github.com/users/BioWareRu/orgs","repos_url":"https://api.github.com/users/BioWareRu/repos","events_url":"https://api.github.com/users/BioWareRu/events{/privacy}","received_events_url":"https://api.github.com/users/BioWareRu/received_events","type":"Organization","site_admin":false},"repo":{"id":137990332,"node_id":"MDEwOlJlcG9zaXRvcnkxMzc5OTAzMzI=","name":"BioEngine.BRC.Admin","full_name":"BioWareRu/BioEngine.BRC.Admin","private":false,"owner":{"login":"BioWareRu","id":22096408,"node_id":"MDEyOk9yZ2FuaXphdGlvbjIyMDk2NDA4","avatar_url":"https://avatars0.githubusercontent.com/u/22096408?v=4","gravatar_id":"","url":"https://api.github.com/users/BioWareRu","html_url":"https://github.com/BioWareRu","followers_url":"https://api.github.com/users/BioWareRu/followers","following_url":"https://api.github.com/users/BioWareRu/following{/other_user}","gists_url":"https://api.github.com/users/BioWareRu/gists{/gist_id}","starred_url":"https://api.github.com/users/BioWareRu/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BioWareRu/subscriptions","organizations_url":"https://api.github.com/users/BioWareRu/orgs","repos_url":"https://api.github.com/users/BioWareRu/repos","events_url":"https://api.github.com/users/BioWareRu/events{/privacy}","received_events_url":"https://api.github.com/users/BioWareRu/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin","description":"Angular interface for BioEngine.API","fork":false,"url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin","forks_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/forks","keys_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/keys{/key_id}","collaborators_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/teams","hooks_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/hooks","issue_events_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/events{/number}","events_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/events","assignees_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/assignees{/user}","branches_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/branches{/branch}","tags_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/tags","blobs_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/refs{/sha}","trees_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/trees{/sha}","statuses_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/statuses/{sha}","languages_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/languages","stargazers_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/stargazers","contributors_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/contributors","subscribers_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/subscribers","subscription_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/subscription","commits_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/commits{/sha}","git_commits_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/git/commits{/sha}","comments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/comments{/number}","issue_comment_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/comments{/number}","contents_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/contents/{+path}","compare_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/compare/{base}...{head}","merges_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/merges","archive_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/downloads","issues_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues{/number}","pulls_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls{/number}","milestones_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/milestones{/number}","notifications_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/labels{/name}","releases_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/releases{/id}","deployments_url":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/deployments","created_at":"2018-06-20T06:36:26Z","updated_at":"2019-06-25T11:27:13Z","pushed_at":"2019-06-28T05:28:38Z","git_url":"git://github.com/BioWareRu/BioEngine.BRC.Admin.git","ssh_url":"git@github.com:BioWareRu/BioEngine.BRC.Admin.git","clone_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin.git","svn_url":"https://github.com/BioWareRu/BioEngine.BRC.Admin","homepage":null,"size":2713,"stargazers_count":0,"watchers_count":0,"language":"TypeScript","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":5,"license":{"key":"mit","name":"MIT License","spdx_id":"MIT","url":"https://api.github.com/licenses/mit","node_id":"MDc6TGljZW5zZTEz"},"forks":0,"open_issues":5,"watchers":0,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256"},"html":{"href":"https://github.com/BioWareRu/BioEngine.BRC.Admin/pull/256"},"issue":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/256"},"comments":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/issues/256/comments"},"review_comments":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256/comments"},"review_comment":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/pulls/256/commits"},"statuses":{"href":"https://api.github.com/repos/BioWareRu/BioEngine.BRC.Admin/statuses/fd926c4d44f91d084bf0060a6b1af1ce9054e34e"}},"author_association":"CONTRIBUTOR","merged":false,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":null,"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":1,"additions":49,"deletions":49,"changed_files":2}},"public":true,"created_at":"2019-06-28T05:28:39Z","org":{"id":22096408,"login":"BioWareRu","gravatar_id":"","url":"https://api.github.com/orgs/BioWareRu","avatar_url":"https://avatars.githubusercontent.com/u/22096408?"}},{"id":"9911330756","type":"PushEvent","actor":{"id":11215289,"login":"keksobot","display_login":"keksobot","gravatar_id":"","url":"https://api.github.com/users/keksobot","avatar_url":"https://avatars.githubusercontent
ть можно [здесь](https://htmlacademy-javascript.github.io/699545-kekstagram-17/6/)."}},"public":true,"created_at":"2019-06-28T05:28:39Z","org":{"id":14179712,"login":"htmlacademy-javascript","gravatar_id":"","url":"https://api.github.com/orgs/htmlacademy-javascript","avatar_url":"https://avatars.githubusercontent.com/u/14179712?"}},{"id":"9911330754","type":"IssueCommentEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":118408826,"name":"DotNetTechLab/XtermjsWindowsService","url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/issues/21","repository_url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService","labels_url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/issues/21/labels{/name}","comments_url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/issues/21/comments","events_url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/issues/21/events","html_url":"https://github.com/DotNetTechLab/XtermjsWindowsService/pull/21","id":450168030,"node_id":"MDExOlB1bGxSZXF1ZXN0MjgzNTQ0OTUz","number":21,"title":"Bump Microsoft.NET.Test.Sdk from 15.5.0 to 16.1.1","user":{"login":"dependabot-preview[bot]","id":27856297,"node_id":"MDM6Qm90Mjc4NTYyOTc=","avatar_url":"https://avatars3.githubusercontent.com/in/2141?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview%5Bbot%5D","html_url":"https://github.com/apps/dependabot-preview","followers_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"labels":[{"id":1138328712,"node_id":"MDU6TGFiZWwxMTM4MzI4NzEy","url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/labels/dependencies","name":"dependencies","color":"0025ff","default":false}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2019-05-30T07:21:56Z","updated_at":"2019-06-28T05:28:39Z","closed_at":null,"author_association":"NONE","pull_request":{"url":"https://api.github.com/repos/DotNetTechLab/XtermjsWindowsService/pulls/21","html_url":"https://github.com/DotNetTechLab/XtermjsWindowsService/pull/21","diff_url":"https://github.com/DotNetTechLab/XtermjsWindowsService/pull/21.diff","patch_url":"https://github.com/DotNetTechLab/XtermjsWindowsService/pull/21.patch"},"body":"Bumps [Microsoft.NET.Test.Sdk](https://github.com/microsoft/vstest) from 15.5.0 to 16.1.1.\\n<details>\\n<summary>Release notes</summary>\\n\\n*Sourced from [Microsoft.NET.Test.Sdk\'s releases](https://github.com/microsoft/vstest/releases).*\\n\\n> ## v16.1.1\\n> Release Notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1611)\\n> \\n> ## v16.1.0\\n> No release notes provided.\\n> \\n> ## v16.0.2-preview-20190502-01\\n> Release Notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1602-preview-20190502-01)\\n> \\n> ## v16.0.1\\n> Release Notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1601)\\n> \\n> ## v16.0.0-preview-20190203-03\\n> No release notes provided.\\n> \\n> ## v16.0.0-preview-20190201-03\\n> No release notes provided.\\n> \\n> ## v16.0.0-preview-20190124-02\\n> Release Notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md)\\n> \\n> ## v16.0.0-preview-20181205-02\\n> Release Notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md)\\n> \\n> ## v16.0.0-preview-20181128-01\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md)\\n> \\n> ## v15.9.2\\n> No release notes provided.\\n> \\n> ## v15.9.1\\n> No release notes provided.\\n> \\n> ## 15.9.0\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1590)\\n> \\n> ## v15.9.0-preview-20180924-03\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1590-preview-20180924-03)\\n> \\n> ## v15.9.0-preview-20180807-05\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1590-preview-20180807-05)\\n> \\n> ## v15.8.0\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1580).\\n> \\n> ## v15.8.0-preview-20180610-02\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md#1580-preview-20180610-02).\\n> \\n> ## v15.8.0-preview-20180605-02\\n> Release notes [here](https://github.com/Microsoft/vstest-docs/blob/master/docs/releases.md)\\n></tr></table> ... (truncated)\\n</details>\\n<details>\\n<summary>Commits</summary>\\n\\n- [`7d28e20`](https://github.com/microsoft/vstest/commit/7d28e2008209c29289119aa87038dc2858524eef) [Draft] [Design mode] Invoking vstest.console with environment variables ([#2023](https://github-redirect.dependabot.com/microsoft/vstest/issues/2023))\\n- [`93ffe26`](https://github.com/microsoft/vstest/commit/93ffe264079e660ce79c2ac529f60f0e6273bc9b) Upgrading TP version to 16.1.1 ([#2030](https://github-redirect.dependabot.com/microsoft/vstest/issues/2030))\\n- [`c33a84f`](https://github.com/microsoft/vstest/commit/c33a84f6471a7ae3160e72ba0074a085748b338e) Prevent unnecessary progress indicator refresh ([#2024](https://github-redirect.dependabot.com/microsoft/vstest/issues/2024))\\n- [`402060b`](https://github.com/microsoft/vstest/commit/402060be01b134aea1546d3cc3a779ff4d651c5d) Remove redundancies for BuildFromSource fix ([#2017](https://github-redirect.dependabot.com/microsoft/vstest/issues/2017))\\n- [`7909f50`](https://github.com/microsoft/vstest/commit/7909f509be5a979620d8e164be39a7a20dddea59) DataCollector search in output directory ([#2015](https://github-redirect.dependabot.com/microsoft/vstest/issues/2015))\\n- [`06cf5cf`](https://github.com/microsoft/vstest/commit/06cf5cf5d558afe399924714320985639afdd5be) Fix for the trx classname being wrongly stamped when testname and fullqualifi...\\n- [`77ab51b`](https://github.com/microsoft/vstest/commit/77ab51b976b7d2c5a2314f2fce46a604c5680c86) Branding fix for 16.1 release ([#2012](https://github-redirect.dependabot.com/microsoft/vstest/issues/2012))\\n- [`2be4433`](https://github.com/microsoft/vstest/commit/2be4433b9139420bc90d9c2783d887a663332602) Making the TPv2 vsix a system component so that it cannot be disabled by the ...\\n- [`f33bb21`](https://github.com/microsoft/vstest/commit/f33bb21b47b027016959d8385e0f69a7e3ff8027) Update Tp Version ([#2002](https://github-redirect.dependabot.com/microsoft/vstest/issues/2002))\\n- [`0d85a87`](https://github.com/microsoft/vstest/commit/0d85a87caa27a88e6cab3b051fa3abbcf214f042) Fixing the code to preserve newline for adapter logs to stdout ([#1999](https://github-redirect.dependabot.com/microsoft/vstest/issues/1999))\\n- Additional commits viewable in [compare view](https://github.com/microsoft/vstest/compare/v15.5.0...v16.1.1)\\n</details>\\n<br />\\n\\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=Microsoft.NET.Test.Sdk&package-manager=nuget&previous-version=15.5.0&new-version=16.1.1)](https://dependabot.com/compatibility-score.html?dependency-name=Microsoft.NET.Test.Sdk&package-manager=nuget&previous-version=15.5.0&new-version=16.1.1)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\\n- `@dependabot badge me` will comment on this PR with code to add a \\"Dependabot enabled\\" badge to your readme\\n\\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\\n- Update frequency (including time of day and day of week)\\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\\n- Pull request limits (per update run and/or open at any time)\\n- Out-of-range updates (receive only lockfile updates, if desired)\\n- Security updates (receive only security updates, if desired)\\n\\nFinally, you can contact us by mentioning @dependabot.\\n
"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"361f814bae5a2073d624c97fc78b806fa4d5ccd3","before":"c927b028c667f1eef00a6ddee19802b72df84cca","commits":[{"sha":"361f814bae5a2073d624c97fc78b806fa4d5ccd3","author":{"email":"kirbsraspberrypi@gmail.com","name":"kirbsraspberrypi"},"message":"auto upload file","distinct":true,"url":"https://api.github.com/repos/kirbsraspberrypi/124428723/commits/361f814bae5a2073d624c97fc78b806fa4d5ccd3"}]},"public":true,"created_at":"2019-06-28T05:28:38Z"},{"id":"9911330704","type":"IssuesEvent","actor":{"id":37936606,"login":"github-learning-lab[bot]","display_login":"github-learning-lab","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab[bot]","avatar_url":"https://avatars.githubusercontent.com/u/37936606?"},"repo":{"id":194208256,"name":"just-a-rookie-2001/security-on-github","url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github/issues/4","repository_url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github","labels_url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github/issues/4/labels{/name}","comments_url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github/issues/4/comments","events_url":"https://api.github.com/repos/just-a-rookie-2001/security-on-github/issues/4/events","html_url":"https://github.com/just-a-rookie-2001/security-on-github/issues/4","id":461862428,"node_id":"MDU6SXNzdWU0NjE4NjI0Mjg=","number":4,"title":"Find repository vulnerabilities","user":{"login":"github-learning-lab[bot]","id":37936606,"node_id":"MDM6Qm90Mzc5MzY2MDY=","avatar_url":"https://avatars0.githubusercontent.com/in/10572?v=4","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab%5Bbot%5D","html_url":"https://github.com/apps/github-learning-lab","followers_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/repos","events_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events","type":"Bot","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2019-06-28T05:28:38Z","updated_at":"2019-06-28T05:28:38Z","closed_at":null,"author_association":"NONE","body":"## Finding vulnerable dependencies\\n\\nSecurity vulnerabilities can cause a range of problems for your project or the people who use it.  A vulnerability could affect the confidentiality, integrity, or availability of a project.  Sometimes vulnerabilities aren\'t in the code you write, but in the code your project depends on. Staying up-to-date with the most recent versions is the best line of defense.\\n\\nThis repository has some existing dependencies which will need updating to stay secure.\\n\\n### How can we identify dependencies and if they are vulnerable?\\n\\nThis repository is a Node.js project utilizing NPM. Because of that, the `package.json` defines this repository\'s dependencies.  For our time together, we\'ll be focusing on these JavaScript dependencies. Keep in mind that different programming languages may have different dependency files. You might work with a `Gemfile`, `Gemfile.lock`, `*.gemspec`, `requirements.txt`, `pipfile.lock`, or other files.\\n\\nHow can we know these dependencies are secure? It\'s not always easy, but GitHub is watching out.\\n\\n### GitHub\'s security alerts for vulnerable dependencies\\n\\nYou may notice some alerts from GitHub about this repository. You may get an email, or see a yellow bar warning you about the `package.json` file.\\n\\n![dependency vulnerability alert](https://user-images.githubusercontent.com/9906718/46882979-c275b680-ce50-11e8-9f47-2081daf20b98.png)\\n\\nGitHub tracks public vulnerabilities in Ruby gems, NPM, Python, Java, and .Net packages.\\n\\nGitHub receives a notification of a newly-announced vulnerability. Next, we check for repositories that use the affected version of that dependency. We send security alerts to a set of people within those affected repositories. The owners are contacted by default. But, it\'s possible to configure specific teams or individuals to get these important notifications.\\n\\n**GitHub never publicly discloses identified vulnerabilities for any repository.**\\n\\n## Step 2: Find this repository\'s vulnerable dependencies\\n\\nUse GitHub\'s security alerts to identify a vulnerable NPM dependency.\\n\\n### :keyboard: Activity: Identify the suggested version update\\n\\n1. Click the **Insights** tab in your repository.\\n2. On the left hand navigation bar, click **Dependency graph**.\\n3. Scroll down until you see a yellow bar highlighting the dependency named `debug`, and click on the right hand side of the yellow `debug` section.\\n4. Take note of the suggested version.\\n5. Comment in this issue with the suggested update version.\\n\\n\\n> _**GitHub Enterprise Server only:** This is all possible on GitHub Enterprise through GitHub Connect. It may take up to an hour to refresh the alerts and make them visible. After waiting a reasonable amount of time, if you are still not seeing the yellow bar in the Dependency Graph, you may want to contact your administrator. In the mean time, to move along with the course, we\'ll give you a hint - the recommended upgraded version is `2.6.9`._\\n\\nFor a printable version of the steps in this course, check out the [Quick Reference Guide](https://lab.github.com/public/securing-your-workflows.pdf).\\n\\n<hr>\\n<h3 align=\\"center\\">Return to this issue for my next comment.</h3>\\n"}},"public":true,"created_at":"2019-06-28T05:28:38Z"},{"id":"9911330702","type":"ForkEvent","actor":{"id":2306515,"login":"aung2phyowai","display_login":"aung2phyowai","gravatar_id":"","url":"https://api.github.com/users/aung2phyowai","avatar_url":"https://avatars.githubusercontent.com/u/2306515?"},"repo":{"id":110072728,"name":"DeepBCI/Deep-BCI","url":"https://api.github.com/repos/DeepBCI/Deep-BCI"},"payload":{"forkee":{"id":194211711,"node_id":"MDEwOlJlcG9zaXRvcnkxOTQyMTE3MTE=","name":"Deep-BCI","full_name":"aung2phyowai/Deep-BCI","private":false,"owner":{"login":"aung2phyowai","id":2306515,"node_id":"MDQ6VXNlcjIzMDY1MTU=","avatar_url":"https://avatars0.githubusercontent.com/u/2306515?v=4","gravatar_id":"","url":"https://api.github.com/users/aung2phyowai","html_url":"https://github.com/aung2phyowai","followers_url":"https://api.github.com/users/aung2phyowai/followers","following_url":"https://api.github.com/users/aung2phyowai/following{/other_user}","gists_url":"https://api.github.com/users/aung2phyowai/gists{/gist_id}","starred_url":"https://api.github.com/users/aung2phyowai/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/aung2phyowai/subscriptions","organizations_url":"https://api.github.com/users/aung2phyowai/orgs","repos_url":"https://api.github.com/users/aung2phyowai/repos","events_url":"https://api.github.com/users/aung2phyowai/events{/privacy}","received_events_url":"https://api.github.com/users/aung2phyowai/received_events","type":"User","site_admin":false},"html_url":"https://github.com/aung2phyowai/Deep-BCI","description":"An open software package to develop BCI based brain and cognitive computing technology for recognizing user\'s intention using deep learning","fork":true,"url":"https://api.github.com/repos/aung2phyowai/Deep-BCI","forks_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/forks","keys_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/keys{/key_id}","collaborators_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/teams","hooks_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/hooks","issue_events_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/issues/events{/number}","events_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/events","assignees_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/assignees{/user}","branches_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/branches{/branch}","tags_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/tags","blobs_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/git/refs{/sha}","trees_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/git/trees{/sha}","statuses_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/statuses/{sha}","languages_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/languages","stargazers_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/stargazers","contributors_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/contributors","subscribers_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/subscribers","subscription_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/subscription","commits_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/commits{/sha}","git_commits_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/git/commits{/sha}","comments_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/comments{/number}","issue_comment_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/issues/comments{/number}","contents_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/contents/{+path}","compare_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/compare/{base}...{head}","merges_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/merges","archive_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/downloads","issues_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/issues{/number}","pulls_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/pulls{/number}","milestones_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/milestones{/number}","notifications_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/labels{/name}","releases_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/releases{/id}","deployments_url":"https://api.github.com/repos/aung2phyowai/Deep-BCI/deployments","created_at":"2019-06-28T05:28:38Z","updated_at":"2019-06-26T01:37:44Z","pushed_at":"2019-06-17T06:57:59Z","git_url":"git://github.com/aung2phyowai/Deep-BCI.git","ssh_url":"git@github.com:aung2phyowai/Deep-BCI.git","clone_url":"https://github.com/aung2phyowai/Deep-BCI.git","svn_url":"https://github.com/aung2phyowai/Deep-BCI","homepage":null,"size":410894,"stargazers_count":0,"watchers_count":0,"language":null,"has_issues":false,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":0,"license":null,"forks":0,"open_issues":0,"watchers":0,"default_branch":"master","public":true}},"public":true,"created_at":"2019-06-28T05:28:38Z"},{"id":"9911330700","type":"PullRequestEvent","actor":{"id":42781255,"login":"ThomasUtsey","display_login":"ThomasUtsey","gravatar_id":"","url":"https://api.github.com/users/ThomasUtsey","avatar_url":"https://avatars.githubusercontent.com/u/42781255?"},"repo":{"id":185896674,"name":"labslibrarypt3/LabsLibraryPT3_BE","url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE"},"payload":{"action":"closed","number":78,"pull_request":{"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls/78","id":292692898,"node_id":"MDExOlB1bGxSZXF1ZXN0MjkyNjkyODk4","html_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE/pull/78","diff_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE/pull/78.diff","patch_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE/pull/78.patch","issue_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/78","number":78,"state":"closed","locked":false,"title":"Development","user":{"login":"ThomasUtsey","id":42781255,"node_id":"MDQ6VXNlcjQyNzgxMjU1","avatar_url":"https://avatars3.githubusercontent.com/u/42781255?v=4","gravatar_id":"","url":"https://api.github.com/users/ThomasUtsey","html_url":"https://github.com/ThomasUtsey","followers_url":"https://api.github.com/users/ThomasUtsey/followers","following_url":"https://api.github.com/users/ThomasUtsey/following{/other_user}","gists_url":"https://api.github.com/users/ThomasUtsey/gists{/gist_id}","starred_url":"https://api.github.com/users/ThomasUtsey/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users
url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/events{/number}","events_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/events","assignees_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/assignees{/user}","branches_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/branches{/branch}","tags_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/tags","blobs_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/refs{/sha}","trees_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/trees{/sha}","statuses_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/statuses/{sha}","languages_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/languages","stargazers_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/stargazers","contributors_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/contributors","subscribers_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/subscribers","subscription_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/subscription","commits_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits{/sha}","git_commits_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/commits{/sha}","comments_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/comments{/number}","issue_comment_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/comments{/number}","contents_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/contents/{+path}","compare_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/compare/{base}...{head}","merges_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/merges","archive_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/downloads","issues_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues{/number}","pulls_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls{/number}","milestones_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/milestones{/number}","notifications_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/labels{/name}","releases_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/releases{/id}","deployments_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/deployments","created_at":"2019-05-10T01:26:33Z","updated_at":"2019-06-26T01:49:58Z","pushed_at":"2019-06-28T05:28:38Z","git_url":"git://github.com/labslibrarypt3/LabsLibraryPT3_BE.git","ssh_url":"git@github.com:labslibrarypt3/LabsLibraryPT3_BE.git","clone_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE.git","svn_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE","homepage":null,"size":344,"stargazers_count":0,"watchers_count":0,"language":"JavaScript","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":1,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":0,"license":{"key":"mit","name":"MIT License","spdx_id":"MIT","url":"https://api.github.com/licenses/mit","node_id":"MDc6TGljZW5zZTEz"},"forks":1,"open_issues":0,"watchers":0,"default_branch":"master"}},"base":{"label":"labslibrarypt3:master","ref":"master","sha":"ba5970c90e5d259bb8e22fad77529a99fd214784","user":{"login":"labslibrarypt3","id":50470163,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwNDcwMTYz","avatar_url":"https://avatars2.githubusercontent.com/u/50470163?v=4","gravatar_id":"","url":"https://api.github.com/users/labslibrarypt3","html_url":"https://github.com/labslibrarypt3","followers_url":"https://api.github.com/users/labslibrarypt3/followers","following_url":"https://api.github.com/users/labslibrarypt3/following{/other_user}","gists_url":"https://api.github.com/users/labslibrarypt3/gists{/gist_id}","starred_url":"https://api.github.com/users/labslibrarypt3/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/labslibrarypt3/subscriptions","organizations_url":"https://api.github.com/users/labslibrarypt3/orgs","repos_url":"https://api.github.com/users/labslibrarypt3/repos","events_url":"https://api.github.com/users/labslibrarypt3/events{/privacy}","received_events_url":"https://api.github.com/users/labslibrarypt3/received_events","type":"Organization","site_admin":false},"repo":{"id":185896674,"node_id":"MDEwOlJlcG9zaXRvcnkxODU4OTY2NzQ=","name":"LabsLibraryPT3_BE","full_name":"labslibrarypt3/LabsLibraryPT3_BE","private":false,"owner":{"login":"labslibrarypt3","id":50470163,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwNDcwMTYz","avatar_url":"https://avatars2.githubusercontent.com/u/50470163?v=4","gravatar_id":"","url":"https://api.github.com/users/labslibrarypt3","html_url":"https://github.com/labslibrarypt3","followers_url":"https://api.github.com/users/labslibrarypt3/followers","following_url":"https://api.github.com/users/labslibrarypt3/following{/other_user}","gists_url":"https://api.github.com/users/labslibrarypt3/gists{/gist_id}","starred_url":"https://api.github.com/users/labslibrarypt3/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/labslibrarypt3/subscriptions","organizations_url":"https://api.github.com/users/labslibrarypt3/orgs","repos_url":"https://api.github.com/users/labslibrarypt3/repos","events_url":"https://api.github.com/users/labslibrarypt3/events{/privacy}","received_events_url":"https://api.github.com/users/labslibrarypt3/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE","description":"BE","fork":false,"url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE","forks_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/forks","keys_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/keys{/key_id}","collaborators_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/teams","hooks_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/hooks","issue_events_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/events{/number}","events_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/events","assignees_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/assignees{/user}","branches_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/branches{/branch}","tags_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/tags","blobs_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/refs{/sha}","trees_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/trees{/sha}","statuses_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/statuses/{sha}","languages_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/languages","stargazers_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/stargazers","contributors_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/contributors","subscribers_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/subscribers","subscription_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/subscription","commits_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits{/sha}","git_commits_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/git/commits{/sha}","comments_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/comments{/number}","issue_comment_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/comments{/number}","contents_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/contents/{+path}","compare_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/compare/{base}...{head}","merges_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/merges","archive_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/downloads","issues_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues{/number}","pulls_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls{/number}","milestones_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/milestones{/number}","notifications_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/labels{/name}","releases_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/releases{/id}","deployments_url":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/deployments","created_at":"2019-05-10T01:26:33Z","updated_at":"2019-06-26T01:49:58Z","pushed_at":"2019-06-28T05:28:38Z","git_url":"git://github.com/labslibrarypt3/LabsLibraryPT3_BE.git","ssh_url":"git@github.com:labslibrarypt3/LabsLibraryPT3_BE.git","clone_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE.git","svn_url":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE","homepage":null,"size":344,"stargazers_count":0,"watchers_count":0,"language":"JavaScript","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":1,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":0,"license":{"key":"mit","name":"MIT License","spdx_id":"MIT","url":"https://api.github.com/licenses/mit","node_id":"MDc6TGljZW5zZTEz"},"forks":1,"open_issues":0,"watchers":0,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls/78"},"html":{"href":"https://github.com/labslibrarypt3/LabsLibraryPT3_BE/pull/78"},"issue":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/78"},"comments":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/issues/78/comments"},"review_comments":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls/78/comments"},"review_comment":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/pulls/78/commits"},"statuses":{"href":"https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/statuses/26ec0d6fffff65448247d7e8b95863a6bea94031"}},"author_association":"COLLABORATOR","merged":true,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":{"login":"ThomasUtsey","id":42781255,"node_id":"MDQ6VXNlcjQyNzgxMjU1","avatar_url":"https://avatars3.githubusercontent.com/u/42781255?v=4","gravatar_id":"","url":"https://api.github.com/users/ThomasUtsey","html_url":"https://github.com/ThomasUtsey","followers_url":"https://api.github.com/users/ThomasUtsey/followers","following_url":"https://api.github.com/users/ThomasUtsey/following{/other_user}","gists_url":"https://api.github.com/users/ThomasUtsey/gists{/gist_id}","starred_url":"https://api.github.com/users/ThomasUtsey/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users
url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [AWSSDK.CloudWatchLogs](https://github.com/aws/aws-sdk-net) from 3.3.4.2 to 3.3.100.41.\\n<details>\\n<summary>Changelog</summary>\\n\\n*Sourced from [AWSSDK.CloudWatchLogs\'s changelog](https://github.com/aws/aws-sdk-net/blob/master/SDK.CHANGELOG.md).*\\n\\n> ### 3.3.541.0 (2019-06-27 18:14 UTC)\\n> * DirectConnect (3.3.103.0)\\n> \\t* Tags will now be included in the API responses of all supported resources (Virtual interfaces, Connections, Interconnects and LAGs). You can also add tags while creating these resources.\\n> * EC2InstanceConnect (3.3.100.0)\\n> \\t* Amazon EC2 Instance Connect is a simple and secure way to connect to your instances using Secure Shell (SSH). With EC2 Instance Connect, you can control SSH access to your instances using AWS Identity and Access Management (IAM) policies as well as audit connection requests with AWS CloudTrail events. In addition, you can leverage your existing SSH keys or further enhance your security posture by generating one-time use SSH keys each time an authorized user connects.\\n> * Pinpoint (3.3.100.40)\\n> \\t* This release includes editorial updates for the Amazon Pinpoint API documentation.\\n> * WorkSpaces (3.3.103.0)\\n> \\t* Added support for the WorkSpaces restore feature and copying WorkSpaces Images across AWS Regions.\\n> * Core 3.3.103.4\\n> \\t* Updating endpoints.json file\\n> \\n> \\n> \\t* All services packages updated to require new Core\\n> \\n> ### 3.3.540.1 (2019-06-27 00:22 UTC)\\n> * DynamoDBv2 (3.3.101.30)\\n> \\t* Documentation updates for dynamodb\\n> * Core 3.3.103.3\\n> \\t* Updating endpoints.json file\\n> \\n> \\n> \\t* All services packages updated to require new Core\\n> \\n> ### 3.3.540.0 (2019-06-26 19:13 UTC)\\n> * ApiGatewayV2 (3.3.102.0)\\n> \\t* You can now perform tag operations on ApiGatewayV2 Resources (typically associated with WebSocket APIs)\\n> * CodeCommit (3.3.103.0)\\n> \\t* This release supports better exception handling for merges.\\n> * Core 3.3.103.2\\n> \\t* Updating endpoints.json file\\n> \\n> \\n> \\t* All services packages updated to require new Core\\n> \\n> ### 3.3.539.0 (2019-06-25 18:51 UTC)\\n> * EC2 (3.3.118.0)\\n> \\t* Starting today, you can use Traffic Mirroring  to copy network traffic from an elastic network interface of Amazon EC2 instances and then send it to out-of-band security and monitoring appliances for content inspection, threat monitoring, and troubleshooting. These appliances can be deployed as individual instances, or as a fleet of instances behind a Network Load Balancer with a User Datagram Protocol (UDP) listener. Traffic Mirroring supports filters and packet truncation, so that you only extract the traffic of interest to monitor by using monitoring tools of your choice.\\n> * EKS (3.3.101.35)\\n> \\t* Changing Amazon EKS full service name to Amazon Elastic Kubernetes Service.\\n> \\n> ### 3.3.538.0 (2019-06-24 18:18 UTC)\\n> * APIGateway (3.3.102.0)\\n> \\t* Customers can pick different security policies (TLS version + cipher suite) for custom domains in API Gateway\\n> * ApiGatewayV2 (3.3.101.0)\\n> \\t* Customers can get information about security policies set on custom domain resources in API Gateway\\n> * ApplicationInsights (3.3.100.0)\\n> \\t* CloudWatch Application Insights detects errors and exceptions from logs, including .NET custom application logs, SQL Server logs, IIS logs, and more, and uses a combination of built-in rules and machine learning, such as dynamic baselining, to identify common problems. You can then easily drill into specific issues with CloudWatch Automatic Dashboards that are dynamically generated. These dashboards contain the most recent alarms, a summary of relevant metrics, and log snippets to help you identify root cause.\\n> * ElasticLoadBalancingV2 (3.3.102.0)\\n> \\t* This release adds support for UDP on Network Load Balancers\\n></tr></table> ... (truncated)\\n</details>\\n<details>\\n<summary>Commits</summary>\\n\\n- See full diff in [compare view](https://github.com/aws/aws-sdk-net/commits)\\n</details>\\n<br />\\n\\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=AWSSDK.CloudWatchLogs&package-manager=nuget&previous-version=3.3.4.2&new-version=3.3.100.41)](https://dependabot.com/compatibility-score.html?dependency-name=AWSSDK.CloudWatchLogs&package-manager=nuget&previous-version=3.3.4.2&new-version=3.3.100.41)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\\n- `@dependabot badge me` will comment on this PR with code to add a \\"Dependabot enabled\\" badge to your readme\\n\\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\\n- Update frequency (including time of day and day of week)\\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\\n- Pull request limits (per update run and/or open at any time)\\n- Out-of-range updates (receive only lockfile updates, if desired)\\n- Security updates (receive only security updates, if desired)\\n\\nFinally, you can contact us by mentioning @dependabot.\\n\\n</details>","created_at":"2019-06-28T05:28:37Z","updated_at":"2019-06-28T05:28:37Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch
url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/compare/{base}...{head}","merges_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/merges","archive_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/downloads","issues_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/issues{/number}","pulls_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/pulls{/number}","milestones_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/milestones{/number}","notifications_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/labels{/name}","releases_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/releases{/id}","deployments_url":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/deployments","created_at":"2018-05-02T13:25:41Z","updated_at":"2018-05-03T07:28:53Z","pushed_at":"2019-06-28T05:28:36Z","git_url":"git://github.com/mleyb/serilog-sinks-awscloudwatch.git","ssh_url":"git@github.com:mleyb/serilog-sinks-awscloudwatch.git","clone_url":"https://github.com/mleyb/serilog-sinks-awscloudwatch.git","svn_url":"https://github.com/mleyb/serilog-sinks-awscloudwatch","homepage":null,"size":98,"stargazers_count":0,"watchers_count":0,"language":"C#","has_issues":false,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":8,"license":{"key":"apache-2.0","name":"Apache License 2.0","spdx_id":"Apache-2.0","url":"https://api.github.com/licenses/apache-2.0","node_id":"MDc6TGljZW5zZTI="},"forks":0,"open_issues":8,"watchers":0,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/pulls/78"},"html":{"href":"https://github.com/mleyb/serilog-sinks-awscloudwatch/pull/78"},"issue":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/issues/78"},"comments":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/issues/78/comments"},"review_comments":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/pulls/78/comments"},"review_comment":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/pulls/78/commits"},"statuses":{"href":"https://api.github.com/repos/mleyb/serilog-sinks-awscloudwatch/statuses/7681da5f4bb9b94f4a70d0325a5d704961113de6"}},"author_association":"NONE","merged":false,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":null,"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":1,"additions":1,"deletions":1,"changed_files":1}},"public":true,"created_at":"2019-06-28T05:28:38Z"},{"id":"9911330681","type":"WatchEvent","actor":{"id":18701550,"login":"AdityaHarindar","display_login":"AdityaHarindar","gravatar_id":"","url":"https://api.github.com/users/AdityaHarindar","avatar_url":"https://avatars.githubusercontent.com/u/18701550?"},"repo":{"id":136541011,"name":"riscv/riscv-c-api-doc","url":"https://api.github.com/repos/riscv/riscv-c-api-doc"},"payload":{"action":"started"},"public":true,"created_at":"2019-06-28T05:28:37Z","org":{"id":10872782,"login":"riscv","gravatar_id":"","url":"https://api.github.com/orgs/riscv","avatar_url":"https://avatars.githubusercontent.com/u/10872782?"}},{"id":"9911330676","type":"PushEvent","actor":{"id":30368443,"login":"Tobenaii","display_login":"Tobenaii","gravatar_id":"","url":"https://api.github.com/users/Tobenaii","avatar_url":"https://avatars.githubusercontent.com/u/30368443?"},"repo":{"id":193991189,"name":"Tobenaii/ClobTheBuilder","url":"https://api.github.com/repos/Tobenaii/ClobTheBuilder"},"payload":{"push_id":3762296138,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":
ingondemand","url":"https://api.github.com/repos/hpcugent/hanythingondemand"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/comments/298457233","pull_request_review_id":255589776,"id":298457233,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDI5ODQ1NzIzMw==","diff_hunk":"@@ -0,0 +1,288 @@\\n+# #\\n+# Copyright 2019-2019 Ghent University\\n+#\\n+# This file is part of hanythingondemand\\n+# originally created by the HPC team of Ghent University (http://ugent.be/hpc/en),\\n+# with support of Ghent University (http://ugent.be/hpc),\\n+# the Flemish Supercomputer Centre (VSC) (https://vscentrum.be/nl/en),\\n+# the Hercules foundation (http://www.herculesstichting.be/in_English)\\n+# and the Department of Economy, Science and Innovation (EWI) (http://www.ewi-vlaanderen.be/en).\\n+#\\n+# http://github.com/hpcugent/hanythingondemand\\n+#\\n+# hanythingondemand is free software: you can redistribute it and/or modify\\n+# it under the terms of the GNU General Public License as published by\\n+# the Free Software Foundation v2.\\n+#\\n+# hanythingondemand is distributed in the hope that it will be useful,\\n+# but WITHOUT ANY WARRANTY; without even the implied warranty of\\n+# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the\\n+# GNU General Public License for more details.\\n+#\\n+# You should have received a copy of the GNU General Public License\\n+# along with hanythingondemand. If not, see <http://www.gnu.org/licenses/>.\\n+# #\\n+\\"\\"\\"\\n+Implementation of the Slurm resource manager\\n+\\n+@author: Kenneth Hoste (Ghent University)\\n+\\"\\"\\"\\n+import os\\n+import re\\n+import sys\\n+import tempfile\\n+from vsc.utils import fancylogger\\n+\\n+from hod.commands.command import Sbatch, Scancel, Squeue\\n+from hod.rmscheduler.resourcemanagerscheduler import ResourceManagerScheduler\\n+\\n+\\n+_log = fancylogger.getLogger(fname=False)\\n+\\n+\\n+class SlurmJob(object):\\n+    \'\'\'\\n+    Data type representing a job\\n+    \'\'\'\\n+    __slots__ = [\'jobid\', \'state\', \'hosts\']\\n+\\n+    def __init__(self, jobid, jstate, hosts):\\n+        self.jobid = jobid\\n+        self.state = jstate\\n+        self.hosts = hosts\\n+\\n+    def __str__(self):\\n+        return \\"Jobid %s state %s ehosts %s\\" % (self.jobid, self.state, self.hosts)\\n+\\n+    def __repr__(self):\\n+        return \'SlurmJob(jobid=%s, state=%s, hosts=%s)\' % (self.jobid, self.state, self.hosts)\\n+\\n+\\n+def format_state(jobs):\\n+    \'\'\'Given a list of SlurmJob objects, print them.\'\'\'\\n+    temp = \\"Id %s State %s Node %s\\"\\n+    if len(jobs) == 0:\\n+        msg = \\"No jobs found.\\"\\n+    elif len(jobs) == 1:\\n+        job = jobs[0]\\n+        msg = \\"Found 1 job \\" + temp % (job.jobid, job.state, job.hosts)\\n+    else:\\n+        msg = \\"Found %s jobs\\\\n\\" % len(jobs)\\n+        for j in jobs:\\n+            msg += \\"    %s\\\\n\\" + temp % (j.jobid, j.state, j.hosts)\\n+    _log.debug(\\"msg %s\\", msg)\\n+\\n+    return msg\\n+\\n+\\n+class Slurm(ResourceManagerScheduler):\\n+    \\"\\"\\"Interaction with torque\\"\\"\\"\\n+    def __init__(self, options):\\n+        super(Slurm, self).__init__(options)\\n+        self.log = fancylogger.getLogger(self.__class__.__name__, fname=False)\\n+        self.options = options\\n+        self.log.debug(\\"Provided options %s\\", options)\\n+\\n+        self.vars = {\\n+            \'cwd\': \'SLURM_SUBMIT_DIR\',\\n+            \'jobid\': \'SLURM_JOBID\',\\n+        }\\n+\\n+    def submit(self, txt):\\n+        \\"\\"\\"Submit the jobscript txt, set self.jobid\\"\\"\\"\\n+        self.log.debug(\\"Going to submit script %s\\", txt)\\n+\\n+        fh, scriptfn = tempfile.mkstemp()\\n+        f = os.fdopen(fh, \'w\')\\n+        self.log.debug(\\"Writing temp jobscript to %s\\" % scriptfn)\\n+        f.write(txt)\\n+        f.close()\\n+\\n+        stdout, stderr = Sbatch(scriptfn).run()\\n+        if stderr:\\n+            raise RuntimeError(\\"Job submission failed: %s\\" % stderr)\\n+\\n+        jobid_regex = re.compile(\\"Submitted batch job ([0-9]+)\\")\\n+        res = jobid_regex.search(stdout)\\n+        if res:\\n+            self.jobid = res.group(1)\\n+            self.log.debug(\\"Succesful jobsubmission returned jobid %s\\", self.jobid)\\n+        else:\\n+            raise RuntimeError(\\"Failed to determine job ID from output: %s\\" % stdout)\\n+\\n+        os.remove(scriptfn)\\n+\\n+    def state(self, jobid=None, job_filter=None):\\n+        \\"\\"\\"Return the state of job with id jobid\\"\\"\\"\\n+        if jobid is None:\\n+            jobid = self.jobid\\n+\\n+        state = self.info(jobid, types=[\'STATE\', \'NODELIST\'], job_filter=job_filter)\\n+\\n+        jid = [x[\'JOBID\'] for x in state]\\n+\\n+        jstate = [x.get(\'STATE\', None) for x in state]\\n+\\n+        def get_uniq_hosts(txt, num=1):\\n+            \\"\\"\\"txt host1/cpuid+host2/cpuid\\n+                - num: number of nodes to return\\n+            \\"\\"\\"\\n+            res = []\\n+            for h_c in txt.split(\',\'):\\n+                h = h_c.split(\'/\')[0]\\n+                if h in res:\\n+                    continue\\n+                res.append(h)\\n+            return res[:num]\\n+\\n+        ehosts = [get_uniq_hosts(x.get(\'NODELIST\', \'\')) for x in state]\\n+\\n+        self.log.debug(\\"Jobid  %s jid %s state %s ehosts %s (%s)\\", jobid, jid, jstate, ehosts, state)\\n+\\n+        def _first_or_blank(x):\\n+            \'\'\'Only use first node (don\'t use [0], job in Q have empty list\'\'\'\\n+            return \'\' if len(x) == 0 else x[0]\\n+\\n+        jobs = [SlurmJob(j, s, h) for (j, s, h) in zip(jid, jstate, map(_first_or_blank, ehosts))]\\n+        return jobs\\n+\\n+    def list_jobs(self, jobid=None):\\n+        \\"\\"\\"Return list of currently queued/running jobs.\\"\\"\\"\\n+\\n+        # https://gist.github.com/stevekm/7831fac98473ea17d781330baa0dd7aa\\n+        stdout, stderr = Squeue(jobid).run()\\n+        if stderr:\\n+            raise RuntimeError(\\"squeue failed: %s\\" % stderr)\\n+\\n+        # expected format:\\n+        # CLUSTER: cluster_name\\n+        # LABEL1|LABEL2|...\\n+        # job1_value1|job1_value2|...\\n+        # job2_value1|job2_value2|...\\n+\\n+        lines = stdout.splitlines()\\n+\\n+        # first line can be ignored\\n+        lines.pop(0)\\n+\\n+        # 2nd line is name of fields\\n+        keys = lines.pop(0).split(\'|\')\\n+\\n+        jobs = []\\n+        for line in lines:\\n+            values = line.split(\'|\')\\n+            job = dict((key, val) for key, val in zip(keys, values))\\n+            jobs.append(job)\\n+\\n+        return jobs\\n+\\n+    def info(self, jobid, types=None, job_filter=None):\\n+        \\"\\"\\"Return jobinfo\\"\\"\\"\\n+\\n+        if job_filter is None:\\n+            job_filter = {}\\n+        self.log.debug(\\"Job filter passed %s\\", job_filter)\\n+        if self.job_filter is not None:\\n+            self.log.debug(\\"Job filter update with %s\\", self.job_filter)\\n+            job_filter.update(self.job_filter)\\n+        self.log.debug(\\"Job filter used %s\\", job_filter)\\n+\\n+        # only known filter is based on job name\\n+        job_name_filter = job_filter.pop(\'Job_Name\', None)\\n+        self.log.debug(\\"Job name filter: %s\\" % job_name_filter)\\n+        if job_filter:\\n+            raise NotImplementedError(\\"Unknown job filter keys encountered: %s\\" % job_filter.keys())\\n+\\n+        # get list of all jobs\\n+        jobs = self.list_jobs(jobid)\\n+        self.log.debug(\\"List of jobs before filtering: %s\\", jobs)\\n+\\n+        res = []\\n+        for job in jobs:\\n+            if job_name_filter:\\n+                regex = re.compile(job_name_filter)\\n+                if not regex.search(job[\'NAME\']):\\n+                    continue\\n+            res.append(job)\\n+\\n+        self.log.info(\\"Found job info %s\\", res)\\n+        return res\\n+\\n+    def remove(self, jobid=None):\\n+        \\"\\"\\"Remove the job with id jobid.\\"\\"\\"\\n+        if jobid is None:\\n+            jobid = self.jobid\\n+\\n+        stdout, stderr = Scancel(jobid).run()\\n+        if stderr:\\n+            sys.stderr.write(\\"scancel failed: %s\\\\n\\" % stderr)","path":"hod/rmscheduler/rm_slurm.py","position":218,"original_position":218,"commit_id":"de78cdaee9042c0d2c1a146cb7d2acd1c5e9591c","original_commit_id":"de78cdaee9042c0d2c1a146cb7d2acd1c5e9591c","user":{"login":"stdweird","id":1517606,"node_id":"MDQ6VXNlcjE1MTc2MDY=","avatar_url":"https://avatars3.githubusercontent.com/u/1517606?v=4","gravatar_id":"","url":"https://api.github.com/users/stdweird","html_url":"https://github.com/stdweird","followers_url":"https://api.github.com/users/stdweird/followers","following_url":"https://api.github.com/users/stdweird/following{/other_user}","gists_url":"https://api.github.com/users/stdweird/gists{/gist_id}","starred_url":"https://api.github.com/users/stdweird/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/stdweird/subscriptions","organizations_url":"https://api.github.com/users/stdweird/orgs","repos_url":"https://api.github.com/users/stdweird/repos","events_url":"https://api.github.com/users/stdweird/events{/privacy}","received_events_url":"https://api.github.com/users/stdweird/received_events","type":"User","site_admin":false},"body":"add jobid to message","created_at":"2019-06-28T05:28:37Z","updated_at":"2019-06-28T05:28:37Z","html_url":"https://github.com/hpcugent/hanythingondemand/pull/205#discussion_r298457233","pull_request_url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205","author_association":"MEMBER","_links":{"self":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/comments/298457233"},"html":{"href":"https://github.com/hpcugent/hanythingondemand/pull/205#discussion_r298457233"},"pull_request":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205"}}},"pull_request":{"url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205","id":292538824,"node_id":"MDExOlB1bGxSZXF1ZXN0MjkyNTM4ODI0","html_url":"https://github.com/hpcugent/hanythingondemand/pull/205","diff_url":"https://github.com/hpcugent/hanythingondemand/pull/205.diff","patch_url":"https://github.com/hpcugent/hanythingondemand/pull/205.patch","issue_url":"https://api.github.com/repos/hpcugent/hanythingondemand/issues/205","number":205,"state":"open","locked":false,"title":"add support for running HoD on top of Slurm, and make it the default resource manager (HPC-7164)","user":{"login":"boegel","id":620876,"node_id":"MDQ6VXNlcjYyMDg3Ng==","avatar_url":"https://avatars1.githubusercontent.com/u/620876?v=4","gravatar_id":"","url":"https://api.github.com/users/boegel","html_url":"https://github.com/boegel","followers_url":"https://api.github.com/users/boegel/followers","following_url":"https://api.github.com/users/boegel/following{/other_user}","gists_url":"https://api.github.com/users/boegel/gists{/gist_id}","starred_url":"https://api.github.com/users/boegel/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/boegel/subscriptions","organizations_url":"https://api.github.com/users/boegel/orgs","repos_url":"https://api.github.com/users/boegel/repos","events_url":"https://api.github.com/users/boegel/events{/privacy}","received_events_url":"https://api.github.com/users/boegel/received_events","type":"User","site_admin":false},"body":"The implementation could probably be a bit cleaner, and this will need some more love to make the tests happy, but these changes seem to be sufficient to make things work more-or-less as expected...\\r\\n\\r\\nTested using `Spark-2.4.0-Hadoop-2.9.2` dist and `Python/2.7.15-intel-2018b`:\\r\\n\\r\\n* running Hadoop WordCount example by submitting a script via `hod batch`\\r\\n* creating HoD cluster using `hod create`, connecting to it via `hod connect` and running Hadoop WordCount manually","created_at":"2019-06-27T17:47:10Z","updated_at":"2019-06-28T05:28:37Z","closed_at":null,"merged_at":null,"merge_commit_sha":"0d990a697225e129484504c291dbdb4669de7a32","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205/commits","review_comments_url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205/comments","review_comment_url":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/comments{/number}","comments_url":"https://api.github.com/repos/hpcugent/hanythingondemand/issues/205/comments","statuses_url":"https://api.github.com/repos/hpcugent/hanythingondemand/statuses/de78cdaee9042c0d2c1a146cb7d2acd1c5e9591c","head":{"label":"boegel:Slurm","ref":"Slurm","sha":"de78cdaee9042c0d2c1a146cb7d2acd1c5e9591c","user":{"login":"boegel","id":620876,"node_id":"MDQ6VXNlcjYyMDg3Ng==","avatar_url":"https://avatars1.githubusercontent.com/u/620876?v=4","gravatar_id":"","url":"https://api.github.com/users/boegel","html_url":"https://github.com/boegel","followers_url":"https://api.github.com/users/boegel/followers","following_url":"https://api.github.com/users/boegel/following{/other_user}","gists_url":"https://api.github.com/users/boegel/gists{/gist_id}","starred_url":"https://api.github.com/users/boegel/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/boegel/subscriptions","organizations_url":"https://api.github.com/users/boegel/orgs","repos_url":"https://api.github.com/users/boegel/repos","events_url":"https://api.github.com/users/boegel/events{/privacy}","received_events_url":"https://api.github.com/users/boegel/received_events","type":"User","site_admin":false},"repo":{"id":36071550,"node_id":"MDEwOlJlcG9zaXRvcnkzNjA3MTU1MA==","name":"hanythingondemand","full_name":"boegel/hanythingondemand","private":false,"owner":{"login":"boegel","id":620876,"node_id":"MDQ6VXNlcjYyMDg3Ng==","avatar_url":"https://avatars1.githubusercontent.com/u/620876?v=4","gravatar_id":"","url":"https://api.github.com/users/boegel","html_url":"https://github.com/boegel","followers_url":"https://api.github.com/users/boegel/followers","following_url":"https://api.github.com/users/boegel/following{/other_user}","gists_url":"https://api.github.com/users/boegel/gists{/gist_id}","starred_url":"https://api.github.com/users/boegel/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/boegel/subscriptions","organizations_url":"https://api.github.com/users/boegel/orgs","repos_url":"https://api.github.com/users/boegel/repos","events_url":"https://api.github.com/users/boegel/events{/privacy}","received_events_url":"https://api.github.com/users/boegel/received_events","type":"User","site_admin":false},"html_url":"https://github.com/boegel/hanythingondemand","description":"hanythingondemand provides a set of scripts to easily set up an ad-hoc Hadoop cluster through PBS jobs ","fork":true,"url":"https://api.github.com/repos/boegel/hanythingondemand","forks_url":"https://api.github.com/repos/boegel/hanythingondemand/forks","keys_url":"https://api.github.com/repos/boegel/hanythingondemand/keys{/key_id}","collaborators_url":"https://api.github.com/repos/boegel/hanythingondemand/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/boegel/hanythingondemand/teams","hooks_url":"https://api.github.com/repos/boegel/hanythingondemand/hooks","issue_events_url":"https://api.github.com/repos/boegel/hanythingondemand/issues/events{/number}","events_url":"https://api.github.com/repos/boegel/hanythingondemand/events","assignees_url":"https://api.github.com/repos/boegel/hanythingondemand/assignees{/user}","branches_url":"https://api.github.com/repos/boegel/hanythingondemand/branches{/branch}","tags_url":"https://api.github.com/repos/boegel/hanythingondemand/tags","blobs_url":"https://api.github.com/repos/boegel/hanythingondemand/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/boegel/hanythingondemand/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/boegel/hanythingondemand/git/refs{/sha}","trees_url":"https://api.github.com/repos/boegel/hanythingondemand/git/trees{/sha}","statuses_url":"https://api.github.com/repos/boegel/hanythingondemand/statuses/{sha}","languages_url":"https://api.github.com/repos/boegel/hanythingondemand/languages","stargazers_url":"https://api.github.com/repos/boegel/hanythingondemand/stargazers","contributors_url":"https://api.github.com/repos/boegel/hanythingondemand/contributors","subscribers_url":"https://api.github.com/repos/boegel/hanythingondemand/subscribers","subscription_url":"https://api.github.com/repos/boegel/hanythingondemand/subscription","commits_url":"https://api.github.com/repos/boegel/hanythingondemand/commits{/sha}","git_commits_url":"https://api.github.com/repos/boegel/hanythingondemand/git/commits{/sha}","comments_url":"https://api.github.com/repos/boegel/hanythingondemand/comments{/number}","issue_comment_url":"https://api.github.com/repos/boegel/hanythingondemand/issues/comments{/number}","contents_url":"https://api.github.com/repos/boegel/hanythingondemand/contents/{+path}","compare_url":"https://api.github.com/repos/boegel/hanythingondemand/compare/{base}...{head}","merges_url":"https://api.github.com/repos/boegel/hanythingondemand/merges","archive_url":"https://api.github.com/repos/boegel/hanythingondemand/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos
notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/hpcugent/hanythingondemand/labels{/name}","releases_url":"https://api.github.com/repos/hpcugent/hanythingondemand/releases{/id}","deployments_url":"https://api.github.com/repos/hpcugent/hanythingondemand/deployments","created_at":"2014-03-11T13:48:31Z","updated_at":"2019-01-24T13:13:54Z","pushed_at":"2019-06-27T18:21:31Z","git_url":"git://github.com/hpcugent/hanythingondemand.git","ssh_url":"git@github.com:hpcugent/hanythingondemand.git","clone_url":"https://github.com/hpcugent/hanythingondemand.git","svn_url":"https://github.com/hpcugent/hanythingondemand","homepage":"https://hod.readthedocs.org","size":2146,"stargazers_count":12,"watchers_count":12,"language":"Python","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":5,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":42,"license":{"key":"gpl-2.0","name":"GNU General Public License v2.0","spdx_id":"GPL-2.0","url":"https://api.github.com/licenses/gpl-2.0","node_id":"MDc6TGljZW5zZTg="},"forks":5,"open_issues":42,"watchers":12,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205"},"html":{"href":"https://github.com/hpcugent/hanythingondemand/pull/205"},"issue":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/issues/205"},"comments":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/issues/205/comments"},"review_comments":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205/comments"},"review_comment":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/pulls/205/commits"},"statuses":{"href":"https://api.github.com/repos/hpcugent/hanythingondemand/statuses/de78cdaee9042c0d2c1a146cb7d2acd1c5e9591c"}},"author_association":"MEMBER"}},"public":true,"created_at":"2019-06-28T05:28:37Z","org":{"id":1515263,"login":"hpcugent","gravatar_id":"","url":"https://api.github.com/orgs/hpcugent","avatar_url":"https://avatars.githubusercontent.com/u/1515263?"}},{"id":"9911330667","type":"PushEvent","actor":{"id":6836144,"login":"waynemcfetridge","display_login":"waynemcfetridge","gravatar_id":"","url":"https://api.github.com/users/waynemcfetridge","avatar_url":"https://avatars.githubusercontent.com/u/6836144?"},"repo":{"id":188137589,"name":"stratapp/stratapp.github.io","url":"https://api.github.com/repos/stratapp/stratapp.github.io"},"payload":{"push_id":3762296131,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d232379bf4c4d37f09f9e05cb474a0cec3b70c30","before":"eb6698570dba1f7ea4341f43f9b74e349af0df79","commits":[{"sha":"d232379bf4c4d37f09f9e05cb474a0cec3b70c30","author":{"email":"sales@stratapp.ai","name":"sales @stratapp.ai"},"message":"Deploy from Forestry.io","distinct":true,"url":"https://api.github.com/repos/stratapp/stratapp.github.io/commits/d232379bf4c4d37f09f9e05cb474a0cec3b70c30"}]},"public":true,"created_at":"2019-06-28T05:28:37Z","org":{"id":50934395,"login":"stratapp","gravatar_id":"","url":"https://api.github.com/orgs/stratapp","avatar_url":"https://avatars.githubusercontent.com/u/50934395?"}},{"id":"9911330668","type":"PullRequestEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":111722247,"name":"alizain/ismaili-volunteer","url":"https://api.github.com/repos/alizain/ismaili-volunteer"},"payload":{"action":"opened","number":487,"pull_request":{"url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487","id":292692945,"node_id":"MDExOlB1bGxSZXF1ZXN0MjkyNjkyOTQ1","html_url":"https://github.com/alizain/ismaili-volunteer/pull/487","diff_url":"https://github.com/alizain/ismaili-volunteer/pull/487.diff","patch_url":"https://github.com/alizain/ismaili-volunteer/pull/487.patch","issue_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/487","number":487,"state":"open","locked":false,"title":"Bump plug_cowboy from 2.0.2 to 2.1.0","user":{"login":"dependabot-preview[bot]","id":27856297,"node_id":"MDM6Qm90Mjc4NTYyOTc=","avatar_url":"https://avatars3.githubusercontent.com/in/2141?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview%5Bbot%5D","html_url":"https://github.com/apps/dependabot-preview","followers_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [plug_cowboy](https://github.com/elixir-plug/plug_cowboy) from 2.0.2 to 2.1.0.\\n<details>\\n<summary>Changelog</summary>\\n\\n*Sourced from [plug_cowboy\'s changelog](https://github.com/elixir-plug/plug_cowboy/blob/master/CHANGELOG.md).*\\n\\n> ## v2.1.0\\n> \\n> ### Enhancement\\n> \\n>   * Add `Plug.Cowboy.Drainer` for connection draining\\n</details>\\n<details>\\n<summary>Commits</summary>\\n\\n- [`7bf68cd`](https://github.com/elixir-plug/plug_cowboy/commit/7bf68cd757c1a052e227112b681b77066fd84d2b) Release v2.1.0\\n- [`9a029fd`](https://github.com/elixir-plug/plug_cowboy/commit/9a029fdfee6569147a114082b227d4457d118ca3) Add a connection drainer ([#14](https://github-redirect.dependabot.com/elixir-plug/plug_cowboy/issues/14))\\n- [`60765d6`](https://github.com/elixir-plug/plug_cowboy/commit/60765d60d4fbd961d2034cd22990d9bd5671f2fa) Use x509 to generate certs in test ([#13](https://github-redirect.dependabot.com/elixir-plug/plug_cowboy/issues/13))\\n- See full diff in [compare view](https://github.com/elixir-plug/plug_cowboy/compare/v2.0.2...v2.1.0)\\n</details>\\n<br />\\n\\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=plug_cowboy&package-manager=hex&previous-version=2.0.2&new-version=2.1.0)](https://dependabot.com/compatibility-score.html?dependency-name=plug_cowboy&package-manager=hex&previous-version=2.0.2&new-version=2.1.0)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\nDependabot will **not** automatically merge this PR because it includes a minor update to a production dependency.\\n\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\\n- `@dependabot badge me` will comment on this PR with code to add a \\"Dependabot enabled\\" badge to your readme\\n\\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\\n- Update frequency (including time of day and day of week)\\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\\n- Pull request limits (per update run and/or open at any time)\\n- Out-of-range updates (receive only lockfile updates, if desired)\\n- Security updates (receive only security updates, if desired)\\n\\nFinally, you can contact us by mentioning @dependabot.\\n\\n</details>","created_at":"2019-06-28T05:28:37Z","updated_at":"2019-06-28T05:28:37Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/commits","review_comments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/comments","review_comment_url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/comments{/number}","comments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/487/comments","statuses_url":"https://api.github.com/repos/alizain/ismaili-volunteer/statuses/ca195c256be06c5356bc19caa2a9da344053e52b","head":{"label":"alizain:dependabot/hex/plug_cowboy-2.1.0","ref":"dependabot/hex/plug_cowboy-2.1.0","sha":"ca195c256be06c5356bc19caa2a9da344053e52b","user":{"login":"alizain","id":2343007,"node_id":"MDQ6VXNlcjIzNDMwMDc=","avatar_url":"https://avatars2.githubusercontent.com/u/2343007?v=4","gravatar_id":"","url":"https://api.github.com/users/alizain","html_url":"https://github.com/alizain","followers_url":"https://api.github.com/users/alizain/followers","following_url":"https://api.github.com/users/alizain/following{/other_user}","gists_url":"https://api.github.com/users/alizain/gists{/gist_id}","starred_url":"https://api.github.com/users/alizain/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alizain/subscriptions","organizations_url":"https://api.github.com/users/alizain/orgs","repos_url":"https://api.github.com/users/alizain/repos","events_url":"https://api.github.com/users/alizain/events{/privacy}","received_events_url":"https://api.github.com/users/alizain/received_events","type":"User","site_admin":false},"repo":{"id":111722247,"node_id":"MDEwOlJlcG9zaXRvcnkxMTE3MjIyNDc=","name":"ismaili-volunteer","full_name":"alizain/ismaili-volunteer","private":false,"owner":{"login":"alizain","id":2343007,"node_id":"MDQ6VXNlcjIzNDMwMDc=","avatar_url":"https://avatars2.githubusercontent.com/u/2343007?v=4","gravatar_id":"","url":"https://api.github.com/users/alizain","html_url":"https://github.com/alizain","followers_url":"https://api.github.com/users/alizain/followers","following_url":"https://api.github.com/users/alizain/following{/other_user}","gists_url":"https://api.github.com/users/alizain/gists{/gist_id}","starred_url":"https://api.github.com/users/alizain/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alizain/subscriptions","organizations_url":"https://api.github.com/users/alizain/orgs","repos_url":"https://api.github.com/users/alizain/repos","events_url":"https://api.github.com/users/alizain/events{/privacy}","received_events_url":"https://api.github.com/users/alizain/received_events","type":"User","site_admin":false},"html_url":"https://github.com/alizain/ismaili-volunteer","description":"Core server for IsmailiVolunteer","fork":false,"url":"https://api.github.com/repos/alizain/ismaili-volunteer","forks_url":"https://api.github.com/repos/alizain/ismaili-volunteer/forks","keys_url":"https://api.github.com/repos/alizain/ismaili-volunteer/keys{/key_id}","collaborators_url":"https://api.github.com/repos/alizain/ismaili-volunteer/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/alizain/ismaili-volunteer/teams","hooks_url":"https://api.github.com/repos/alizain/ismaili-volunteer/hooks","issue_events_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/events{/number}","events_url":"https://api.github.com/repos/alizain/ismaili-volunteer/events","assignees_url":"https://api.github.com/repos/alizain/ismaili-volunteer/assignees{/user}","branches_url":"https://api.github.com/repos/alizain/ismaili-volunteer/branches{/branch}","tags_url":"https://api.github.com/repos/alizain/ismaili-volunteer/tags","blobs_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/refs{/sha}","trees_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/trees{/sha}","statuses_url":"https://api.github.com/repos/alizain/ismaili-volunteer/statuses/{sha}","languages_url":"https://api.github.com/repos/alizain/ismaili-volunteer/languages","stargazers_url":"https://api.github.com/repos/alizain/ismaili-volunteer/stargazers","contributors_url":"https://api.github.com/repos/alizain/ismaili-volunteer/contributors","subscribers_url":"https://api.github.com/repos/alizain/ismaili-volunteer/subscribers","subscription_url":"https://api.github.com/repos/alizain/ismaili-volunteer/subscription","commits_url":"https://api.github.com/repos/alizain/ismaili-volunteer/commits{/sha}","git_commits_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/commits{/sha}","comments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/comments{/number}","issue_comment_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/comments{/number}","contents_url":"https://api.github.com/repos/alizain/ismaili-volunteer/contents/{+path}","compare_url":"https://api.github.com/repos/alizain/ismaili-volunteer/compare/{base}...{head}","merges_url":"https://api.github.com/repos/alizain/ismaili-volunteer/merges","archive_url":"https://api.github.com/repos/alizain/ismaili-volunteer/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/alizain/ismaili-volunteer/downloads","issues_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues{/number}","pulls_url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls{/number}","milestones_url":"https://api.github.com/repos/alizain/ismaili-volunteer/milestones{/number}","notifications_url":"https://api.github.com/repos/alizain/ismaili-volunteer/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/alizain/ismaili-volunteer/labels{/name}","releases_url":"https://api.github.com/repos/alizain/ismaili-volunteer/releases{/id}","deployments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/deployments","created_at":"2017-11-22T19:04:32Z","updated_at":"2019-06-27T06:04:38Z","pushed_at":"2019-06-28T05:28:36Z","git_url":"git://github.com/alizain/ismaili-volunteer.git","ssh_url":"git@github.com:alizain/ismaili-volunteer.git","clone_url":"https://github.com/alizain/ismaili-volunteer.git","svn_url":"https://github.com/alizain/ismaili-volunteer","homepage":"","size":18156,"stargazers_count":0,"watchers_count":0,"language":"Elixir","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":26,"license":null,"forks":0,"open_issues":26,"watchers":0,"default_branch":"master"}},"base":{"label":"alizain:master","ref":"master","sha":"be5f588612ff3b5e54dd9b5497bd6771afdade39","user":{"login":"alizain","id":2343007,"node_id":"MDQ6VXNlcjIzNDMwMDc=","avatar_url":"https://avatars2.githubusercontent.com/u/2343007?v=4","gravatar_id":"","url":"https://api.github.com/users/alizain","html_url":"https://github.com/alizain","followers_url":"https://api.github.com/users/alizain/followers","following_url":"https://api.github.com/users/alizain/following{/other_user}","gists_url":"https://api.github.com/users/alizain/gists{/gist_id}","starred_url":"https://api.github.com/users/alizain/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alizain/subscriptions","organizations_url":"https://api.github.com/users/alizain/orgs","repos_url":"https://api.github.com/users/alizain/repos","events_url":"https://api.github.com/users/alizain/events{/privacy}","received_events_url":"https://api.github.com/users/alizain/received_events","type":"User","site_admin":false},"repo":{"id":111722247,"node_id":"MDEwOlJlcG9zaXRvcnkxMTE3MjIyNDc=","name":"ismaili-volunteer","full_name":"alizain/ismaili-volunteer","private":false,"owner":{"login":"alizain","id":2343007,"node_id":"MDQ6VXNlcjIzNDMwMDc=","avatar_url":"https://avatars2.githubusercontent.com/u/2343007?v=4","gravatar_id":"","url":"https://api.github.com/users/alizain","html_url":"https://github.com/alizain","followers_url":"https://api.github.com/users/alizain/followers","following_url":"https://api.github.com/users/alizain/following{/other_user}","gists_url":"https://api.github.com/users/alizain/gists{/gist_id}","starred_url":"https://api.github.com/users/alizain/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alizain/subscriptions","organizations_url":"https://api.github.com/users/alizain/orgs","repos_url":"https://api.github.com/users/alizain/repos","events_url":"https://api.github.com/users/alizain/events{/privacy}","received_events_url":"https://api.github.com/users/alizain/received_events","type":"User","site_admin":false},"html_url":"https://github.com/alizain/ismaili-volunteer","description":"Core server for IsmailiVolunteer","fork":false,"url":"https://api.github.com/repos/alizain/ismaili-volunteer","forks_url":"https://api.github.com/repos/alizain/ismaili-volunteer/forks","keys_url":"https://api.github.com/repos/alizain/ismaili-volunteer/keys{/key_id}","collaborators_url":"https://api.github.com/repos/alizain/ismaili-volunteer/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/alizain/ismaili-volunteer/teams","hooks_url":"https://api.github.com/repos/alizain/ismaili-volunteer/hooks","issue_events_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/events{/number}","events_url":"https://api.github.com/repos/alizain/ismaili-volunteer/events","assignees_url":"https://api.github.com/repos/alizain/ismaili-volunteer/assignees{/user}","branches_url":"https://api.github.com/repos/alizain/ismaili-volunteer/branches{/branch}","tags_url":"https://api.github.com/repos/alizain/ismaili-volunteer/tags","blobs_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/refs{/sha}","trees_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/trees{/sha}","statuses_url":"https://api.github.com/repos/alizain/ismaili-volunteer/statuses/{sha}","languages_url":"https://api.github.com/repos/alizain/ismaili-volunteer/languages","stargazers_url":"https://api.github.com/repos/alizain/ismaili-volunteer/stargazers","contributors_url":"https://api.github.com/repos/alizain/ismaili-volunteer/contributors","subscribers_url":"https://api.github.com/repos/alizain/ismaili-volunteer/subscribers","subscription_url":"https://api.github.com/repos/alizain/ismaili-volunteer/subscription","commits_url":"https://api.github.com/repos/alizain/ismaili-volunteer/commits{/sha}","git_commits_url":"https://api.github.com/repos/alizain/ismaili-volunteer/git/commits{/sha}","comments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/comments{/number}","issue_comment_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/comments{/number}","contents_url":"https://api.github.com/repos/alizain/ismaili-volunteer/contents/{+path}","compare_url":"https://api.github.com/repos/alizain/ismaili-volunteer/compare/{base}...{head}","merges_url":"https://api.github.com/repos/alizain/ismaili-volunteer/merges","archive_url":"https://api.github.com/repos/alizain/ismaili-volunteer/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/alizain/ismaili-volunteer/downloads","issues_url":"https://api.github.com/repos/alizain/ismaili-volunteer/issues{/number}","pulls_url":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls{/number}","milestones_url":"https://api.github.com/repos/alizain/ismaili-volunteer/milestones{/number}","notifications_url":"https://api.github.com/repos/alizain/ismaili-volunteer/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/alizain/ismaili-volunteer/labels{/name}","releases_url":"https://api.github.com/repos/alizain/ismaili-volunteer/releases{/id}","deployments_url":"https://api.github.com/repos/alizain/ismaili-volunteer/deployments","created_at":"2017-11-22T19:04:32Z","updated_at":"2019-06-27T06:04:38Z","pushed_at":"2019-06-28T05:28:36Z","git_url":"git://github.com/alizain/ismaili-volunteer.git","ssh_url":"git@github.com:alizain/ismaili-volunteer.git","clone_url":"https://github.com/alizain/ismaili-volunteer.git","svn_url":"https://github.com/alizain/ismaili-volunteer","homepage":"","size":18156,"stargazers_count":0,"watchers_count":0,"language":"Elixir","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":0,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":26,"license":null,"forks":0,"open_issues":26,"watchers":0,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487"},"html":{"href":"https://github.com/alizain/ismaili-volunteer/pull/487"},"issue":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/487"},"comments":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/issues/487/comments"},"review_comments":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/comments"},"review_comment":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/commits"},"statuses":{"href":"https://api.github.com/repos/alizain/ismaili-volunteer/statuses/ca195c256be06c5356bc19caa2a9da344053e52b"}},"author_association":"CONTRIBUTOR","merged":false,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":null,"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":1,"additions":1,"deletions":1,"changed_files":1}},"public":true,"created_at":"2019-06-28T05:28:37Z"}]'
# Out:
# '[{"id":"9911330792","type":"PushEvent","actor":{"id":11312017,"login":"pbaffiliate4","display_login":"pbaffiliate4","gravatar_id":"","url":"https://api.github.com/users/pbaffiliate4","avatar_url":"https://avatars.githubusercontent.com/u/11312017?"},"repo":{"id":153577238,"name":"pbaffiliate4/repoForSettings","url":"https://api.github.com/repos/pbaffiliate4/repoForSettings"},"payload":{"push_id":3762296191,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"be9d8ea6b6737192cd4710bf8884125c92acbcc5","before":"bc9fd090c7811ba2b489ef60571abd8c5d413f23","commits":[{"sha":"be9d8ea6b6737192cd4710bf8884125c92acbcc5","author":{"email":"pbaffiliate4@gmail.com","name":"Afaf Zakhya"},"message":"Test - Clear repository branch","distinct":true,"url":"https://api.github.com/repos/pbaffiliate4/repoForSettings/commits/be9d8ea6b6737192cd4710bf8884125c92acbcc5"}]},"public":true,"created_at":"2019-06-28T05:28:39Z"},{"id":"9911330783","type":"PullRequestEvent","actor":{"id":10598,"login":"ketan
# ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13112504215',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 285155887,
#    'name': 'direwolf-github/my-app-4aa26e7b',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app-4aa26e7b'},
#   'payload': {'ref': 'branch-599e7b9c',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-05T02:24:41Z'},
#  {'id': '13112504213',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 308430,
#    'login': 'mokevnin',
#    'display_login': 'mokevnin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mokevnin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/308430?'},
#   'repo': {'id': 261513187,
#    'name': 'hexlet-basics/hexlet-basics',
# ...

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f2a1b49-cd61a3f6e4d0469c57fb959a'},
#  'json': None,
#  'origin': '1.165.198.108',
#  'url': 'http://httpbin.org/post'}
