# %%
import requests
# 引入函式庫
r = requests.get('https://github.com/timeline.json')
# 想要爬資料的目標網址
response = r.text
# 模擬發送請求的動作

# %%
print(response)
response['message']
# Out:
# {"message":"Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.","documentation_url":"https://docs.github.com/v3/activity/events/#list-public-events"}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-74366ae2a7a5> in <module>
#       1 print(response)
# ----> 2 response['message']
#
# TypeError: string indices must be integers

# %%
print(type(response))

# print(response['message'])
print(response[:100])
# Out:
# <class 'str'>
# {"message":"Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our

# %%
import json
response = json.loads(response)

print(type(response))
print(response['message'])
# Out:
# <class 'dict'>
# Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
</body>
</html>
"""

print(html_doc)
print(type(html_doc))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>
#
# <class 'str'>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, "html5lib")
print(soup)
print(type(soup))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
#
#
# </body></html>
# <class 'bs4.BeautifulSoup'>

# %%
import requests
# 引入函式庫
r = requests.get(' https://www.dcard.tw/f')
# 想要爬資料的目標網址
response = r.text
# 模擬發送請求的動作

# %%
print(type(response))

# print(response['message'])
print(response[:100])
# Out:
# <class 'str'>
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https:

# %%
import requests
# 引入函式庫
r = requests.get('  https://www.zhihu.com/explore')
# 想要爬資料的目標網址
response = r.text
# 模擬發送請求的動作

# %%
print(type(response))

# print(response['message'])
print(response[:100])
# Out:
# <class 'str'>
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Req

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

response = r.text

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
#靜態網頁的資料爬蟲策略
#了解靜態網頁的資料爬蟲策略
#認識適用於靜態網頁爬蟲的相關套件工具：Request
#認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup
#作業目標
#利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：

#Dcard 網址： https://www.dcard.tw/f
#知乎： https://www.zhihu.com/explore
#並且回答下面問題：

#Request 取回之後該怎麼取出資料，資料型態是什麼？
#為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
#觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://cdn.amplitude.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="ima

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ => ', type(r.text))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>  <class 'str'>

# %%
soup = BeautifulSoup(r.text, "html5lib")

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link crossorigin="true" href="https://www.googletagmanager.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://certify.alexametrics.com" rel="dns-prefetch"/><link href="https://cloudfront-labs.amazonaws.com" rel="dns-prefetch"/><link href="https://cdn.amplitude.com" rel="dns-prefetch"/><link href="https://bilanx.dcard.tw" rel="dns-prefetch"/><link href="https://imgur.dcard.tw" rel="dns-prefetch"/><link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/><link href="https://browser.sentry-cdn.com" rel="dns-prefetch"/><link href="https://gcs.dcard.tw" rel="dns-prefetch"/><link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><link href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="ima ...
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category" property="al:ios:url"/><script type="application/ld+json">{"@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/f2cbd27b09ad51de7798.css" rel="preload"/><link href="/_next/static/css/f2cbd27b09ad51de7798.css" rel="stylesheet"/><link as="script" href="/_next/static/chunks/commons.8675f0993b6d916e45f8.js" rel="preload"/><link as="script" href="/_next/static/chunks/353173737b4b76a3ff7c2232702655cefc926dbf.3a1f9f6da0c66bfad90d.js" rel="preload"/><link as="script" href="/_next/static/chunks/ed9f72fa187639af2c5386b75e
-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .cuSyfD::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .cuSyfD:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .cuSyfD::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g11[id="dj0ioy-2"]{content:"cuSyfD,"}/*!sc*/
# .ckFjXQ{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g12[id="dj0ioy-3"]{content:"ckFjXQ,"}/*!sc*/
# .fobpBl{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g17[id="pkcmwm-0"]{content:"fobpBl,"}/*!sc*/
# .bDsRPV{position:relative;background-color:#fff;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .bDsRPV:hover{color:rgba(0,0,0,1);}/*!sc*/
# .bDsRPV::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .gpCfsC{position:relative;background-color:#fff;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .gpCfsC:hover{color:rgba(0,0,0,1);}/*!sc*/
# .gpCfsC::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g18[id="pkcmwm-1"]{content:"bDsRPV,gpCfsC,"}/*!sc*/
# .ipLxJt{border-radius:50%;overflow:hidden;}/*!sc*/
# data-styled.g38[id="yj50et-0"]{content:"ipLxJt,"}/*!sc*/
# .hDEgDT{background:#006ea5;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}/*!sc*/
# .gWqWNL{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g39[id="yj50et-1"]{content:"hDEgDT,gWqWNL,"}/*!sc*/
# .bNSsiw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g42[id="euk31c-0"]{content:"bNSsiw,"}/*!sc*/
# .eWZtAp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g43[id="euk31c-1"]{content:"eWZtAp,"}/*!sc*/
# .jGmQxy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g44[id="euk31c-2"]{content:"jGmQxy,"}/*!sc*/
# .kjqMlj{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,.6);line-height:20px;}/*!sc*/
# .kjqMlj:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g45[id="euk31c-3"]{content:"kjqMlj,"}/*!sc*/
# .gYAZIo{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g46[id="euk31c-4"]{content:"gYAZIo,"}/*!sc*/
# .bZxTQa{background-color:#3397cf !important;}/*!sc*/
# data-styled.g51[id="sc-16d9rxt-0"]{content:"bZxTQa,"}/*!sc*/
# .kIlErb{position:relative;width:100%;height:100%;}/*!sc*/
# data-styled.g53[id="e7vhde-0"]{content:"kIlErb,"}/*!sc*/
# .hzzKkS{position:absolute;top:0;left:0;bottom:0;right:0;}/*!sc*/
# data-styled.g54[id="e7vhde-1"]{content:"hzzKkS,"}/*!sc*/
# .fsfKoE{box-sizing:border-box;}/*!sc*/
# data-styled.g56[id="e7vhde-3"]{content:"fsfKoE,"}/*!sc*/
# .ezriGt{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);left:0;bottom:0;height:var(--track-size);width:100%;}/*!sc*/
# .ezriGt:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g59[id="e7vhde-6"]{content:"ezriGt,"}/*!sc*/
# .bqFoAk{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);width:var(--track-size);height:100%;top:0;right:0;}/*!sc*/
# .bqFoAk:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g60[id="e7vhde-7"]{content:"bqFoAk,"}/*!sc*/
# .cIgzEu{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);height:var(--thumb-size);margin:var(--thumb-margin) 0;}/*!sc*/
# .e7vhde-0:hover .cIgzEu{opacity:1;}/*!sc*/
# .e7vhde-5:hover .cIgzEu{height:var(--track-size);margin:0;}/*!sc*/
# data-styled.g62[id="e7vhde-9"]{content:"cIgzEu,"}/*!sc*/
# .dBVzTW{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);width:var(--thumb-size);margin:0 var(--thumb-margin);}/*!sc*/
# .e7vhde-0:hover .dBVzTW{opacity:1;}/*!sc*/
# .e7vhde-5:hover .dBVzTW{width:var(--track-size);margin:0;}/*!sc*/
# data-styled.g63[id="e7vhde-10"]{content:"dBVzTW,"}/*!sc*/
# .hMgrLe{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g65[id="d4ydwz-0"]{content:"hMgrLe,"}/*!sc*/
# .jUVVNo{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g84[id="fdq12b-0"]{content:"jUVVNo,"}/*!sc*/
# .dyvXrv{position:relative;height:120px;padding:16px 0;width:100%;}/*!sc*/
# data-styled.g117[id="sc-1vxpibn-0"]{content:"dyvXrv,"}/*!sc*/
# .iMghLT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# data-styled.g118[id="cgoejl-0"]{content:"iMghLT,"}/*!sc*/
# .etZPvi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# data-styled.g119[id="cgoejl-1"]{content:"etZPvi,"}/*!sc*/
# .kgjcmW{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;}/*!sc*/
# .kgjcmW:first-child{margin-left:0;}/*!sc*/
# data-styled.g120[id="cgoejl-2"]{content:"kgjcmW,"}/*!sc*/
# .focHUl{padding-left:6px;}/*!sc*/
# data-styled.g121[id="cgoejl-3"]{content:"focHUl,"}/*!sc*/
# .hQbqXK{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g122[id="sc-2rneb0-0"]{content:"hQbqXK,"}/*!sc*/
# .jpxHFH{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g123[id="uj732l-0"]{content:"jpxHFH,"}/*!sc*/
# .cZVDcL{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g124[id="uj732l-1"]{content:"cZVDcL,"}/*!sc*/
# .hClArR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .hClArR:last-child{padding-right:0;}/*!sc*/
# data-styled.g125[id="uj732l-2"]{content:"hClArR,"}/*!sc*/
# .eZEefA{padding-right:8px;}/*!sc*/
# data-styled.g126[id="uj732l-3"]{content:"eZEefA,"}/*!sc*/
# .fmHTBT{position:relative;z-index:1;}/*!sc*/
# data-styled.g127[id="uj732l-4"]{content:"fmHTBT,"}/*!sc*/
# .cImkbF{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g128[id="tgn9uw-0"]{content:"cImkbF,"}/*!sc*/
# .fKzhUx{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g129[id="tgn9uw-1"]{content:"fKzhUx,"}/*!sc*/
# .fydrTe{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g130[id="tgn9uw-2"]{content:"fydrTe,"}/*!sc*/
# .bvimNL{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .bvimNL::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g131[id="tgn9uw-3"]{content:"bvimNL,"}/*!sc*/
# .kjyhMD{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g132[id="tgn9uw-4"]{content:"kjyhMD,"}/*!sc*/
# .qNtjN{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g133[id="tgn9uw-5"]{content:"qNtjN,"}/*!sc*/
# .ddyyhm{margin-right:6px;}/*!sc*/
# data-styled.g134[id="tgn9uw-6"]{content:"ddyyhm,"}/*!sc*/
# .eTvEbo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g145[id="j38qb8-0"]{content:"eTvEbo,"}/*!sc*/
# .icljFh{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g146[id="j38qb8-1"]{content:"icljFh,"}/*!sc*/
# .fNctQD{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .cFXHtn{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.
{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;white-space:nowrap;}/*!sc*/
# data-styled.g629[id="irx12-0"]{content:"kIFLZS,"}/*!sc*/
# .czrrTy{border-left:1px solid rgb(222,222,222);padding-right:10px;height:30px;}/*!sc*/
# data-styled.g630[id="irx12-1"]{content:"czrrTy,"}/*!sc*/
# .ghQcyA{cursor:pointer;border:none;background:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0;height:100%;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;outline:none;}/*!sc*/
# data-styled.g631[id="irx12-2"]{content:"ghQcyA,"}/*!sc*/
# .jkqBeC{margin-left:2px;}/*!sc*/
# data-styled.g633[id="irx12-4"]{content:"jkqBeC,"}/*!sc*/
# .QFIRZ{color:rgba(0,0,0,.35);padding:0 5px;}/*!sc*/
# data-styled.g634[id="irx12-5"]{content:"QFIRZ,"}/*!sc*/
# .bHeRmN{color:#3397cf;padding-left:2px;}/*!sc*/
# data-styled.g635[id="irx12-6"]{content:"bHeRmN,"}/*!sc*/
# .jEIZvY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g636[id="sc-1nqrhll-0"]{content:"jEIZvY,"}/*!sc*/
# .iRqapL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .iRqapL > *{height:100%;width:100%;}/*!sc*/
# data-styled.g637[id="sc-1nqrhll-1"]{content:"iRqapL,"}/*!sc*/
# .hHwzaJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# data-styled.g638[id="sc-1nqrhll-2"]{content:"hHwzaJ,"}/*!sc*/
# .kMxQXI{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;border-radius:4px 4px 0 0;border-bottom:1px solid rgba(0,0,0,0.15);position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;}/*!sc*/
# data-styled.g640[id="sc-1iit2li-1"]{content:"kMxQXI,"}/*!sc*/
# .gmPIua{width:100%;z-index:1;}/*!sc*/
# data-styled.g646[id="sc-1iit2li-7"]{content:"gmPIua,"}/*!sc*/
# .dGuKiv{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g647[id="sc-1kb03aj-0"]{content:"dGuKiv,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 dbwfaq"><div class="dz5d85-0 dzPkkj"><div class="dz5d85-1 eWDkXb"><a class="dqjqtp-0 hYBWFg" href="/f" title="Dcard"><img alt="Dcard" class="sc-139xjgq-0 jgLeGA" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/></a><div class="bxef95-1 YvYdq"><div class="dj0ioy-0 cgyzXj"><form><label class="oo2grd-0 jVzpnh"><div class="oo2grd-2 citS"><input aria-label="搜尋" class="oo2grd-4 fzCZpa dj0ioy-2 cuSyfD" placeholder="搜尋" type="search" value=""/></div></label><button class="dj0ioy-3 ckFjXQ" disabled="" title="搜尋" type="submit"><span class="sc-1f9msxf-0 cHvEAz dj0ioy-7 kDhoQw" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button></form></div></div></div><div class="dz5d85-2 AZMcW" role="navigation"><a class="jjui6k-0 fNctQD sc-1ahzbiw-0 esbQwJ" href="/signup" role="button"><span class="jjui6k-1 RMSCC">註冊 / 登入</span></a><div class="fdq12b-0 jUVVNo"><a class="jjui6k-0 cFXHtn" role="button" title="更多"><span class="jjui6k-1 RMSCC"><span class="sc-1f9msxf-0 fmAtWr jjui6k-2 hnuJId" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="bvk29r-0 lhwOsJ"><div class="bvk29r-1 fOlZNJ"><div class="sc-1bfxmuy-0 oQUdR"><a href="/forum/all"><div class="sc-11gkikh-0 ehfesP"><div class="sc-1bfxmuy-1 gCxJOy"><span class="sc-1f9msxf-0 fmAtWr sc-1bfxmuy-2 kaJNcZ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="gthja3-1 laweKo">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 ehfesP"><div class="sc-1bfxmuy-1 gCxJOy"><span class="sc-1f9msxf-0 fmAtWr sc-1bfxmuy-2 kaJNcZ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="gthja3-1 laweKo">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 ehfesP"><div class="sc-1bfxmuy-1 gCxJOy"><span class="sc-1f9msxf-0 fmAtWr m2vgdk-0 incHse" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></div><div class="gthja3-1 laweKo">好物研究室</div></div></a><div class="e7vhde-0 kIlErb ScrollbarsCustom" style="position:relative"><div clas ...

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ', type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>  <class 'bs4.BeautifulSoup'>

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
url = 'https://www.zhihu.com/explore'

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6,ja;q=0.5',
    'cache-control': 'max-age=0',
    'cookie': '_zap=a5634a47-a806-4828-8ab4-2cbc03734bda; d_c0="AFBoGjc1fg6PTus2_H76YgMM3xvztVHRnCs=|1541767835"; __gads=ID=18e1196642fc5994:T=1544975081:S=ALNI_MZ2lQjiLHPlLxjVqGGH6o-EiL2luQ; z_c0="2|1:0|10:1551204934|4:z_c0|92:Mi4xM1FkMERnQUFBQUFBVUdnYU56Vi1EaVlBQUFCZ0FsVk5SdEJpWFFDUXZ6REVHVWw0QWtXblh6WGt4T183ekdxNFhn|fa542d11758c34207cdd6a1edf85de768ac02624c8cb53aa687017af49accd7b"; tst=r; q_c1=aed50b9b158344d6ac78a230c8970d83|1560948516000|1543510922000; __utmv=51854390.100--|2=registration_date=20190226=1^3=entry_date=20181130=1; _xsrf=13cd498d-6139-4c50-99a6-df5c749dd64c; tgw_l7_route=4860b599c6644634a0abcd4d10d37251; __utma=51854390.567487929.1560948518.1560950333.1562469680.3; __utmb=51854390.0.10.1562469680; __utmc=51854390; __utmz=51854390.1562469680.3.3.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/notebooks/day2-example.ipynb',
    'referer': 'http://localhost:8888/notebooks/day2-example.ipynb',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
}
r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# ��Z��.�s�H�*8����� ��m4�Q�7��Ĭ>v�N��ßu2$s~���ߕA��ۊ�X5ʶ�jYUx�P�لR�p��7�����E%�Ώ��z�T�}�
# �~8����Z�K�~S��
