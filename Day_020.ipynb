# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-21T10:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 9005.93981537437,
#     'CapacityRate': 45.6216398539772,
#     'Status': 5,
#     'Basin_Rain': 6.0,
#     'EffectiveCapacity': 19740.5,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-21T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 870.72,
#     'CapacityRate': 86.89820359281437,
#     'Status': 5,
#     'Basin_Rain': 11.25,
#     'EffectiveCapacity': 1002.0,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-21T10:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 22518.03,
#     'CapacityRate': 67.11682389234139,
#     'Status': 5,
# ...
