# %%
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

# %%
from datetime import datetime, timedelta
date_time = datetime.now() - timedelta(1)
date_time = date_time.strftime("%Y/%m/%d")
print("取得昨天時間：", date_time)
# Out:
# 取得昨天時間： 2020/10/21

# %%
import time
while True:
    browser.execute_script("window.scrollTo(0, 100000);")
    time.sleep(2)
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, "html5lib")
    print(soup.find_all(class_="part_list_2")[-1].find_all('h3')[-1].find(class_="date").text)
    if date_time in soup.find_all(class_="part_list_2")[-1].find_all('h3')[-1].find(class_="date").text:
        print('==== STOP ====')
        break
# Out:
# 2020/10/21 23:40
# ==== STOP ====

# %%
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    if date_time in d.find(class_="date").text :
        break
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# 2020/10/22 09:33 仿照《死亡筆記本》夜神月作息　吊車尾逆襲成學霸
# 2020/10/22 09:30 台東池上秋收稻穗藝術節週末登場！天堂路交管、接駁車資訊一次看
# 2020/10/22 09:28 拜登若當選美國總統　國民黨提撤銷瘦肉精行政命令公決案
# 2020/10/22 09:28 目睹有人騎GoShare「從車庫出來」　網氣炸台人私心：找到騎不了
# 2020/10/22 09:26 正妹自拍「身後窗簾」詭異抖動　衝去拉開一看！嚇壞逃回房間
# 2020/10/22 09:25 川普政府宣布3大對台軍售　嚴德發：證明美方對台海安全重視
# 2020/10/22 09:24 緯創女子公開賽／首日李旻獨走　曾雅妮、程思嘉媽媽當桿弟
# 2020/10/22 09:24 現在是否為打房時機　黃天牧這麼說！
# 2020/10/22 09:22 民怨鈔票太大「塞不下」　林楚茵籲央行改版遭酸「削鈔適夾」
# 2020/10/22 09:21 沙發套40年沒洗！女大生浸泡10分鐘出現驚人一幕　3600萬人看傻
# 2020/10/22 09:18 美國宣布3大對台軍售總值540億　總統府：捍衛台海更有信心
# 2020/10/22 09:18 快訊／新竹平房凌晨竄火！26歲女子重傷困房內　送醫搶救不治
# 2020/10/22 09:15 「五局賽揚」封鎖道奇　光芒洛爾轟陽春砲3局1比0領先
# 2020/10/22 09:14 元大銀行董事長退休！　元大金控：個人健康因素
# 2020/10/22 09:14 8年級生股海筋肉人！藥學系畢業不當藥師　4字箴言2年資產翻1倍
# 2020/10/22 09:14 關之琳、劉嘉玲世紀破冰！　20年閨蜜為台富商撕破臉…1照片成反目關鍵
# 2020/10/22 09:13 阿嬌腫了變大媽？　上直播「真面目現形」火速登熱搜第一
# 2020/10/22 09:10 台鐵鋼軌斷裂⋯張政源剉咧等！林佳龍「撂狠話」：他應負督導責任
# 2020/10/22 09:08 嘉義3車撞一團誰闖紅燈？2人都說是綠燈　女駕駛：我印象中也是
# 2020/10/22 09:07 染髮前先搞懂怎麼鎖色！那些妳不敢碰的Pantone光感髮　不怕褪太快
# 2020/10/22 09:05 台股平盤震盪！大同經營權易主　股價漲2.06%
# 2020/10/22 09:05 美製變陸製　特斯拉歐洲Model 3改由上海工廠製造、進口
# 2020/10/22 09:02 吃咖哩不怕冷！醫推「霜降養生法」2招補身…樂喊：我很少生病
# 105  2020/10/22 00:00           中職／富邦悍將拚接手後首冠　準備上萬條藍色彩帶
#
# [106 rows x 2 columns]

# %%
browser.close()

# %%
# 取得兩小時內的時間
from datetime import datetime, timedelta
two_hours_ago_time = datetime.now() - timedelta(hours=2)

# 取得資料（整理成好的格式）
news = []

for d in soup.find(class_="part_list_2").find_all('h3'):
    # 比兩小時前早的話就結束
    if datetime.strptime(d.find(class_="date").text, '%Y/%m/%d %H:%M') < two_hours_ago_time:
        break
    
    news.append({
        '時間': d.find(class_="date").text,
        '標題': d.find_all('a')[-1].text
    })

import pandas as pd
pd.DataFrame(news)
# Out:
#                   時間                                        標題
# 0   2020/10/22 09:33                   仿照《死亡筆記本》夜神月作息　吊車尾逆襲成學霸
# 1   2020/10/22 09:30            台東池上秋收稻穗藝術節週末登場！天堂路交管、接駁車資訊一次看
# 2   2020/10/22 09:28                拜登若當選美國總統　國民黨提撤銷瘦肉精行政命令公決案
# 3   2020/10/22 09:28         目睹有人騎GoShare「從車庫出來」　網氣炸台人私心：找到騎不了
# 4   2020/10/22 09:26              正妹自拍「身後窗簾」詭異抖動　衝去拉開一看！嚇壞逃回房間
# 5   2020/10/22 09:25              川普政府宣布3大對台軍售　嚴德發：證明美方對台海安全重視
# 6   2020/10/22 09:24               緯創女子公開賽／首日李旻獨走　曾雅妮、程思嘉媽媽當桿弟
# 7   2020/10/22 09:24                         現在是否為打房時機　黃天牧這麼說！
# 8   2020/10/22 09:22              民怨鈔票太大「塞不下」　林楚茵籲央行改版遭酸「削鈔適夾」
# 9   2020/10/22 09:21         沙發套40年沒洗！女大生浸泡10分鐘出現驚人一幕　3600萬人看傻
# 10  2020/10/22 09:18             美國宣布3大對台軍售總值540億　總統府：捍衛台海更有信心
# 11  2020/10/22 09:18             快訊／新竹平房凌晨竄火！26歲女子重傷困房內　送醫搶救不治
# 12  2020/10/22 09:15                「五局賽揚」封鎖道奇　光芒洛爾轟陽春砲3局1比0領先
# 13  2020/10/22 09:14                    元大銀行董事長退休！　元大金控：個人健康因素
# 14  2020/10/22 09:14           8年級生股海筋肉人！藥學系畢業不當藥師　4字箴言2年資產翻1倍
# 15  2020/10/22 09:14        關之琳、劉嘉玲世紀破冰！　20年閨蜜為台富商撕破臉…1照片成反目關鍵
# 16  2020/10/22 09:13                阿嬌腫了變大媽？　上直播「真面目現形」火速登熱搜第一
# 17  2020/10/22 09:10            台鐵鋼軌斷裂⋯張政源剉咧等！林佳龍「撂狠話」：他應負督導責任
# 18  2020/10/22 09:08            嘉義3車撞一團誰闖紅燈？2人都說是綠燈　女駕駛：我印象中也是
# 19  2020/10/22 09:07        染髮前先搞懂怎麼鎖色！那些妳不敢碰的Pantone光感髮　不怕褪太快
# 20  2020/10/22 09:05                   台股平盤震盪！大同經營權易主　股價漲2.06%
# 21  2020/10/22 09:05             美製變陸製　特斯拉歐洲Model 3改由上海工廠製造、進口
# 22  2020/10/22 09:02             吃咖哩不怕冷！醫推「霜降養生法」2招補身…樂喊：我很少生病
# 23  2020/10/22 09:00           新光三越信義今天登場！全台百貨週年慶「最省優惠整理」血拼前必看
# 24  2020/10/22 08:59                   桃園觀音水利池缺水　2噸死魚薰臭白千層林蔭大道
# 25  2020/10/22 08:56            高雄攻堅畫面曝光！嫌持槍與警對峙10分鐘…轉身逃2F畏罪自轟
# 26  2020/10/22 08:53                  翡翠水庫壩頂今實施人工增雨　助增加石門水庫集水量
# 27  2020/10/22 08:51              沒企業敢用他！侏儒症患者開火鍋店圓夢爆紅　諧音取名有意義
# 28  2020/10/22 08:51          逾4000萬人提前投票！美國選民積極支持候選人　川普拜登加緊造勢
# 29  2020/10/22 08:45                日職／陳偉殷再繳優質先發　還是拿不到勝投日網友急道歉
# 30  2020/10/22 08:37            快訊／美國家情報總監：證實俄羅斯和伊朗干預總統大選　恐嚇選民
# 31  2020/10/22 08:33           嫌太冷沒給被子蓋！病患急診狂罵護理師　「手一舉起來」27萬飛了
# 32  2020/10/22 08:33           瘦子「N年前服飾店打工」遭店長酸沒搞頭！　挺過見骨爆血車禍翻身
# 33  2020/10/22 08:31      iPhone 12掀2旋風！史上最小5G手機問世倒數　旗艦小手機擬成主流
# 34  2020/10/22 08:24              快訊／颱風甩水氣！新北基隆升級「大豪雨」　台北宜蘭豪大雨
# 35  2020/10/22 08:18                    瘋電影／花木蘭　每個人都可以是戰將女性當自強
# 36  2020/10/22 08:12             教宗首次清楚表態！　支持同性「民事結合」：他們有權合法成家
# 37  2020/10/22 08:07             ㄇ字型趴地！西門町撿錢哥專勾夾娃娃機下硬幣　一個周末得百元
# 38  2020/10/22 08:05          全班有餅乾唯獨一人沒有！台南幼師被「告上教育局」　尪委屈PO真相
# 39  2020/10/22 08:05                GD穿起女裝比女人還適合！朴敘俊、南柱赫男神帥照齊發
# 40  2020/10/22 08:05  全球最快超跑飆508.73km/h！SSC Tuatara讓法拉利藍寶堅尼都吃癟
# 41  2020/10/22 08:03        一瓶330ml罐裝啤酒等於半碗白飯！　喝多會變胖　3健康危機不輸烈酒
# 42  2020/10/22 08:00            黃明志以5種語言寫成劇本　「拍攝時溝通困難」坦承：這就是現況
# 43  2020/10/22 08:00              吃飽直接睡！新竹全新民宿餐酒館　豆腐乳尬花椒烤雞翅超邪惡
# 44  2020/10/22 07:57        范冰冰穿太貼「狂遮肚」網看傻：這造型別人hold不住　好友爆背後內幕
# 45  2020/10/22 07:48              美媒曝10跡象透露「川普將驚喜勝利」：拜登要勝出毫無邏輯
# 46  2020/10/22 07:46        推出僅6個月！　Quibi創辦人宣布：開始逐步關閉服務　尋找適合買家
# 47  2020/10/22 07:41          黃捷自爆「有人開價5000萬包養」　最狂選民服務曝！一句話洩現實

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

# %%
# 取得三天前下午三點到五點的時間
from datetime import datetime, timedelta

date_time = datetime.now() - timedelta(3)
print("取得昨天時間：", date_time)

date_time_month = date_time.strftime("%m")
date_time_day = date_time.strftime("%d")
print("取得昨天時間（月）：", date_time_month)
print("取得昨天時間（日）：", date_time_day)


three_days_15_clock = datetime.strptime(date_time.strftime("%Y/%m/%d") + ' 15', '%Y/%m/%d %H')
three_days_17_clock = datetime.strptime(date_time.strftime("%Y/%m/%d") + ' 17', '%Y/%m/%d %H')
print("取得昨天下午三點：", three_days_15_clock)
print("取得昨天下午五點：", three_days_17_clock)
# Out:
# 取得昨天時間： 2020-10-19 09:40:30.756478
# 取得昨天時間（月）： 10
# 取得昨天時間（日）： 19
# 取得昨天下午三點： 2020-10-19 15:00:00
# 取得昨天下午五點： 2020-10-19 17:00:00

# %%
# 選擇且點選日期
from selenium.webdriver.support.ui import Select

selM = Select(browser.find_element_by_id("selM"))
selM.select_by_value(date_time_month)
selD = Select(browser.find_element_by_id("selD"))
selD.select_by_value(date_time_day)
browser.find_element_by_id('button').click()

# %%
# 利用 selenium 持續執行下滑的動作，直到取得要求時間內的新聞，表示取得完畢
import time
while True:
    browser.execute_script("window.scrollTo(0, 100000);")
    time.sleep(1)
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, "html5lib")
    new_date = soup.find_all(class_="part_list_2")[-1].find_all('h3')[-1].find(class_="date").text
    print(new_date)
    if datetime.strptime(new_date, '%Y/%m/%d %H:%M') < three_days_15_clock:
        print('==== STOP ====')
        break
# Out:
# 2020/10/19 18:29
# 2020/10/19 18:22
# 2020/10/19 18:09
# 2020/10/19 18:02
# 2020/10/19 17:51
# 2020/10/19 17:42
# 2020/10/19 17:30
# 2020/10/19 17:22
# 2020/10/19 17:13
# 2020/10/19 17:00
# 2020/10/19 16:50
# 2020/10/19 16:39
# 2020/10/19 16:24
# 2020/10/19 16:11
# 2020/10/19 16:00
# 2020/10/19 15:51
# 2020/10/19 15:37
# 2020/10/19 15:24
# 2020/10/19 15:15
# 2020/10/19 15:02
# 2020/10/19 14:56
# ==== STOP ====

# %%
# 取得資料（整理成好的格式）
news = []

for d in soup.find(class_="part_list_2").find_all('h3'):
    # 比兩小時前早的話就結束
    if datetime.strptime(d.find(class_="date").text, '%Y/%m/%d %H:%M') < three_days_15_clock:
        print('==== STOP ====')
        break
    
    if datetime.strptime(d.find(class_="date").text, '%Y/%m/%d %H:%M') < three_days_17_clock:
        news.append({
            '時間': d.find(class_="date").text,
            '標題': d.find_all('a')[-1].text
        })

import pandas as pd
pd.DataFrame(news)
# Out:
# ==== STOP ====
#                    時間                                 標題
# 0    2020/10/19 16:58           台灣天菜打破日本出軌男紀錄　王冠閎ISL一戰成名
# 1    2020/10/19 16:55       缺乏3營養素！乾眼症拖2年「眼皮難閉合」　竟與外食也有關
# 2    2020/10/19 16:54           微風南山餐飲佔比下修10%　疫情成網美餐廳照妖鏡
# 3    2020/10/19 16:53      國發會公布海域潔淨與開放總體計畫　明年將投入26億3千萬元
# 4    2020/10/19 16:53  快訊／新莊桃園交界山谷「1女失蹤」　山友急報案...大批警消搜救
# ..                ...                                ...
# 100  2020/10/19 15:02      疫情衝擊！今年房地合一稅大增　年增92.4％翻倍帶動長照稅
# 101  2020/10/19 15:01    廚神Jason Wang《料理之王》當嚴師：不好吃說好吃沒意思
# 102  2020/10/19 15:01      三星拉開與華為差距　手機全球市佔率8月達22%居市場之冠！
# 103  2020/10/19 15:00   「世界的珠寶盒」八角輪廓太經典　Boucheron、香奈兒入設計
# 104  2020/10/19 15:00        湯濃、肉嫩份量多！台中老牌牛肉麵　桂花酸梅湯免費喝到飽
#
# [105 rows x 2 columns]

# %%
# 關閉瀏覽器

browser.close()
